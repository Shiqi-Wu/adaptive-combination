# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import numpy as np
import matplotlib.pyplot as plt
from toy_model import *
import sys 
import torch
import torch.nn as nn
from torch.optim import Adam
from torch.utils.data import DataLoader, TensorDataset
from torch.optim.lr_scheduler import StepLR

# %%
data_model = reaction_diffusion_equation()
dataset = data_model.genarate_training_data(500, 10, dlt_t = 0.001)

# %%
input_dim = 2
hidden_dims = [64, 64, 64]
m_dim = 16
lambda1, lambda2 = 0.1, 1

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ParaModel(nn.Module):
    def __init__(self, input_dim, hidden_dims, m_dim):
        super(ParaModel, self).__init__()
        layers = []
        prev_dim = input_dim
        for hidden_dim in hidden_dims:
            layers.append(nn.Linear(prev_dim, hidden_dim))
            layers.append(nn.ReLU())
            prev_dim = hidden_dim
        
        self.relu_layers = nn.Sequential(*layers)
        
        self.output_layer = nn.Linear(hidden_dims[-1], m_dim)
        self.W = nn.Parameter(torch.randn(m_dim, m_dim), requires_grad=True)
        
    def forward(self, x):
        x = self.relu_layers(x)
        x = self.output_layer(x)
        return x

    # def orthogonal(self, x):
    #     x = self.forward(x)
    #     x = torch.matmul(x, self.W)
    #     return x

# %%
def custom_loss_function(h_outputs, y, lace, mu, lambda1, lambda2, m_dim):
    # Compute g as the product of mu and lace
    g = mu * lace
    # Compute u_x as the difference between y and g, and remove extra dimensions
    u_x = (y - g).squeeze()

    # Initialize the squared norm of g's projection onto the subspace spanned by h_outputs
    proj_g_norm_squared = 0

    # For each vector in the orthogonal basis h_outputs
    for i in range(m_dim):
        h_i = h_outputs[:, i]
        # Calculate the projection coefficient of g onto h_i and accumulate the squares of these projections
        proj_coefficient = (torch.dot(g.squeeze(), h_i) / torch.dot(h_i, h_i))
        proj_g_norm_squared += proj_coefficient ** 2

    # Initialize the squared norm of u_x's projection onto the subspace spanned by h_outputs
    proj_u_x_norm_squared = 0
    k_i_values = torch.zeros(m_dim, device=h_outputs.device)

    for i in range(m_dim):
        h_i = h_outputs[:, i]
        # Calculate the projection coefficient of u_x onto h_i
        proj_coefficient_u_x = (torch.dot(u_x, h_i) / torch.dot(h_i, h_i))
        proj_u_x_norm_squared += proj_coefficient_u_x ** 2
        k_i_values[i] = proj_coefficient_u_x

    # Define loss1 as the lambda1-weighted squared norm of g's projection
    loss1 = lambda1 * proj_g_norm_squared
    # Define loss2 based on the squared difference between u_x and its projection onto the subspace
    loss2 = lambda2 * torch.sum((torch.matmul(h_outputs, k_i_values.unsqueeze(1)).squeeze() - u_x) ** 2)

    # Calculate the total loss as the sum of loss1 and loss2
    total_loss = loss1 + loss2

    return total_loss, loss1, loss2

# %%
# ans = y - mu * lace
# custom_loss_function(ans, y, lace, mu, lambda1, lambda2, 1)

# %%
dataloader = DataLoader(dataset, batch_size=len(dataset), shuffle=False)
for x, y, lace in dataloader:
    break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 2
#       1 dataloader = DataLoader(dataset, batch_size=len(dataset), shuffle=False)
# ----> 2 for x, y, lace in dataloader:
#       3     break
#
# File ~/anaconda3/envs/torch/lib/python3.9/site-packages/torch/utils/data/dataloader.py:633, in _BaseDataLoaderIter.__next__(self)
#     630 if self._sampler_iter is None:
#     631     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     632     self._reset()  # type: ignore[call-arg]
# --> 633 data = self._next_data()
#     634 self._num_yielded += 1
#     635 if self._dataset_kind == _DatasetKind.Iterable and \
#     636         self._IterableDataset_len_called is not None and \
#     637         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/anaconda3/envs/torch/lib/python3.9/site-packages/torch/utils/data/dataloader.py:677, in _SingleProcessDataLoaderIter._next_data(self)
#     675 def _next_data(self):
#     676     index = self._next_index()  # may raise StopIteration
# --> 677     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     678     if self._pin_memory:
#     679         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/anaconda3/envs/torch/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/anaconda3/envs/torch/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/anaconda3/envs/torch/lib/python3.9/site-packages/torch/utils/data/dataset.py:196, in TensorDataset.__getitem__(self, index)
#     195 def __getitem__(self, index):
# --> 196     return tuple(tensor[index] for tensor in self.tensors)
#
# KeyboardInterrupt:

# %%
lace_mean = torch.mean(lace)
y_mean = torch.mean(y)

mu_numerator = torch.sum((lace - lace_mean) * (y - y_mean))
mu_denominator = torch.sum((lace - lace_mean) ** 2)
mu = mu_numerator / mu_denominator

print("Estimated mu:", mu.item())
# Out:
# Estimated mu: -0.2289697676897049

# %%
model_h = ParaModel(input_dim, hidden_dims, m_dim)
print(model_h)
# Out:
# ParaModel(
#   (relu_layers): Sequential(
#     (0): Linear(in_features=2, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=64, bias=True)
#     (5): ReLU()
#   )
#   (output_layer): Linear(in_features=64, out_features=16, bias=True)
# )

# %%
model_h = torch.load('reaction_diffusion_model_h.pth')

# %%
def train_one_epoch(model, optim, data_loader, epoch, mu, lambda1, lambda2):
    model.train()
    train_loss = 0
    train_loss1 = 0
    train_loss2 = 0

    print(f"Training Epoch: {epoch+1}")
    for x, y, lace in data_loader:
        
        h_outputs = model(torch.cat((x, lace), dim = 1))
        Q, R = torch.linalg.qr(h_outputs, mode='reduced')
        
        # R_inv = torch.linalg.inv(R)

        # with torch.no_grad():
            # model.W.data = R_inv

        # h_outputs = model.orthogonal(x)
        optim.zero_grad()
        loss, loss1, loss2 = custom_loss_function(Q, y, lace, mu, lambda1, lambda2, m_dim)
        loss.backward()
        optim.step()
        # print(loss.item())
        # for name, param in model.named_parameters():
        #     if param.grad is not None:
        #         print(f"Gradient of {name} is {param.grad.norm().item()}")  # 打印梯度的范数


        train_loss += loss.item()
        train_loss1 += loss1.item()
        train_loss2 += loss2.item()
    

    avg_train_loss = train_loss / len(data_loader)
    avg_train_loss1 = train_loss1 / len(data_loader)
    avg_train_loss2 = train_loss2 / len(data_loader)
    print(f"Average Training Loss for Epoch {epoch+1}: {avg_train_loss:.4e}; Loss1: {avg_train_loss1:.4e}; Loss2: {avg_train_loss2:.4e}")

    return avg_train_loss, avg_train_loss1, avg_train_loss2

# %%
optim = Adam(model_h.parameters(), lr=0.001)
dataloader = DataLoader(dataset, batch_size=1024, shuffle=False)
scheduler = StepLR(optim, step_size=50, gamma=0.9)

# %%
epochs = 1000
train_losses = []
train_losses1 = []
train_losses2 = []

# %%
for epoch in range(epochs):
    train_loss, train_loss1, train_loss2 = train_one_epoch(model_h, optim, dataloader, epoch, mu, lambda1, lambda2)
    train_losses.append(train_loss)
    train_losses1.append(train_loss1)
    train_losses2.append(train_loss2)
    scheduler.step()
# Out:
# Training Epoch: 1
# Average Training Loss for Epoch 1: 6.9450e-04; Loss1: 6.8716e-04; Loss2: 7.3434e-06
# Training Epoch: 2
# Average Training Loss for Epoch 2: 6.9616e-04; Loss1: 6.8901e-04; Loss2: 7.1449e-06
# Training Epoch: 3
# Average Training Loss for Epoch 3: 6.9563e-04; Loss1: 6.8828e-04; Loss2: 7.3482e-06
# Training Epoch: 4
# Average Training Loss for Epoch 4: 6.9411e-04; Loss1: 6.8675e-04; Loss2: 7.3545e-06
# Training Epoch: 5
# Average Training Loss for Epoch 5: 6.9231e-04; Loss1: 6.8493e-04; Loss2: 7.3782e-06
# Training Epoch: 6
# Average Training Loss for Epoch 6: 6.9103e-04; Loss1: 6.8371e-04; Loss2: 7.3204e-06
# Training Epoch: 7
# Average Training Loss for Epoch 7: 6.9013e-04; Loss1: 6.8273e-04; Loss2: 7.4020e-06
# Training Epoch: 8
# Average Training Loss for Epoch 8: 6.8965e-04; Loss1: 6.8233e-04; Loss2: 7.3266e-06
# Training Epoch: 9
# Average Training Loss for Epoch 9: 6.8931e-04; Loss1: 6.8194e-04; Loss2: 7.3676e-06
# Training Epoch: 10
# Average Training Loss for Epoch 10: 6.8914e-04; Loss1: 6.8182e-04; Loss2: 7.3114e-06
# Training Epoch: 11
# Average Training Loss for Epoch 11: 6.8901e-04; Loss1: 6.8166e-04; Loss2: 7.3513e-06
# Training Epoch: 12
# Average Training Loss for Epoch 12: 6.8896e-04; Loss1: 6.8168e-04; Loss2: 7.2833e-06
# Training Epoch: 13
# Average Training Loss for Epoch 13: 6.8896e-04; Loss1: 6.8162e-04; Loss2: 7.3457e-06
# Training Epoch: 14
# Average Training Loss for Epoch 14: 6.8905e-04; Loss1: 6.8180e-04; Loss2: 7.2523e-06
# Training Epoch: 15
# Average Training Loss for Epoch 15: 6.8927e-04; Loss1: 6.8188e-04; Loss2: 7.3916e-06
# Training Epoch: 16
# Average Training Loss for Epoch 16: 6.8972e-04; Loss1: 6.8258e-04; Loss2: 7.1394e-06
# Training Epoch: 17
# Average Training Loss for Epoch 17: 6.9052e-04; Loss1: 6.8309e-04; Loss2: 7.4255e-06
# Training Epoch: 18
# Average Training Loss for Epoch 18: 6.9157e-04; Loss1: 6.8447e-04; Loss2: 7.1004e-06
# Training Epoch: 19
# Average Training Loss for Epoch 19: 6.9289e-04; Loss1: 6.8539e-04; Loss2: 7.4973e-06
# Training Epoch: 20
# Average Training Loss for Epoch 20: 6.9330e-04; Loss1: 6.8630e-04; Loss2: 7.0015e-06
# Training Epoch: 21
# Average Training Loss for Epoch 21: 6.9346e-04; Loss1: 6.8599e-04; Loss2: 7.4751e-06
# Training Epoch: 22
# Average Training Loss for Epoch 22: 6.9304e-04; Loss1: 6.8582e-04; Loss2: 7.2241e-06
# Training Epoch: 23
# Average Training Loss for Epoch 23: 6.9288e-04; Loss1: 6.8542e-04; Loss2: 7.4667e-06
# Training Epoch: 24
# Average Training Loss for Epoch 24: 6.9250e-04; Loss1: 6.8524e-04; Loss2: 7.2572e-06
# Training Epoch: 25
# Average Training Loss for Epoch 25: 6.9167e-04; Loss1: 6.8433e-04; Loss2: 7.3353e-06
# Training Epoch: 26
# Average Training Loss for Epoch 26: 6.9117e-04; Loss1: 6.8374e-04; Loss2: 7.4241e-06
# Training Epoch: 27
# Average Training Loss for Epoch 27: 6.9032e-04; Loss1: 6.8302e-04; Loss2: 7.2993e-06
# Training Epoch: 28
# Average Training Loss for Epoch 28: 6.9007e-04; Loss1: 6.8268e-04; Loss2: 7.3906e-06
# Training Epoch: 29
# Average Training Loss for Epoch 29: 6.8943e-04; Loss1: 6.8215e-04; Loss2: 7.2815e-06
# Training Epoch: 30
# Average Training Loss for Epoch 30: 6.8937e-04; Loss1: 6.8200e-04; Loss2: 7.3659e-06
# Training Epoch: 31
# Average Training Loss for Epoch 31: 6.8894e-04; Loss1: 6.8166e-04; Loss2: 7.2713e-06
# Training Epoch: 32
# Average Training Loss for Epoch 32: 6.8898e-04; Loss1: 6.8162e-04; Loss2: 7.3547e-06
# Training Epoch: 33
# Average Training Loss for Epoch 33: 6.8870e-04; Loss1: 6.8144e-04; Loss2: 7.2666e-06
# Training Epoch: 34
# Average Training Loss for Epoch 34: 6.8880e-04; Loss1: 6.8146e-04; Loss2: 7.3408e-06
# Training Epoch: 35
# Average Training Loss for Epoch 35: 6.8862e-04; Loss1: 6.8134e-04; Loss2: 7.2777e-06
# Training Epoch: 36
# Average Training Loss for Epoch 36: 6.8876e-04; Loss1: 6.8142e-04; Loss2: 7.3397e-06
# Training Epoch: 37
# Average Training Loss for Epoch 37: 6.8866e-04; Loss1: 6.8139e-04; Loss2: 7.2677e-06
# Training Epoch: 38
# Average Training Loss for Epoch 38: 6.8882e-04; Loss1: 6.8149e-04; Loss2: 7.3323e-06
# Training Epoch: 39
# Average Training Loss for Epoch 39: 6.8879e-04; Loss1: 6.8146e-04; Loss2: 7.3273e-06
# Training Epoch: 40
# Average Training Loss for Epoch 40: 6.8903e-04; Loss1: 6.8177e-04; Loss2: 7.2596e-06
# Training Epoch: 41
# Average Training Loss for Epoch 41: 6.8904e-04; Loss1: 6.8170e-04; Loss2: 7.3341e-06
# Training Epoch: 42
# Average Training Loss for Epoch 42: 6.8926e-04; Loss1: 6.8197e-04; Loss2: 7.2867e-06
# Training Epoch: 43
# Average Training Loss for Epoch 43: 6.8952e-04; Loss1: 6.8217e-04; Loss2: 7.3539e-06
# Training Epoch: 44
# Average Training Loss for Epoch 44: 6.8998e-04; Loss1: 6.8279e-04; Loss2: 7.1892e-06
# Training Epoch: 45
# Average Training Loss for Epoch 45: 6.9127e-04; Loss1: 6.8373e-04; Loss2: 7.5431e-06
# Training Epoch: 46
# Average Training Loss for Epoch 46: 6.9320e-04; Loss1: 6.8627e-04; Loss2: 6.9303e-06
# Training Epoch: 47
# Average Training Loss for Epoch 47: 6.9517e-04; Loss1: 6.8751e-04; Loss2: 7.6551e-06
# Training Epoch: 48
# Average Training Loss for Epoch 48: 6.9507e-04; Loss1: 6.8803e-04; Loss2: 7.0380e-06
# Training Epoch: 49
# Average Training Loss for Epoch 49: 6.9541e-04; Loss1: 6.8778e-04; Loss2: 7.6264e-06
# Training Epoch: 50
# Average Training Loss for Epoch 50: 6.9374e-04; Loss1: 6.8663e-04; Loss2: 7.1032e-06
# Training Epoch: 51
# Average Training Loss for Epoch 51: 6.9210e-04; Loss1: 6.8468e-04; Loss2: 7.4179e-06
# Training Epoch: 52
# Average Training Loss for Epoch 52: 6.8936e-04; Loss1: 6.8206e-04; Loss2: 7.2971e-06
# Training Epoch: 53
# Average Training Loss for Epoch 53: 6.8820e-04; Loss1: 6.8087e-04; Loss2: 7.3264e-06
# Training Epoch: 54
# Average Training Loss for Epoch 54: 6.8766e-04; Loss1: 6.8036e-04; Loss2: 7.3058e-06
# Training Epoch: 55
# Average Training Loss for Epoch 55: 6.8737e-04; Loss1: 6.8005e-04; Loss2: 7.3196e-06
# Training Epoch: 56
# Average Training Loss for Epoch 56: 6.8726e-04; Loss1: 6.7995e-04; Loss2: 7.3095e-06
# Training Epoch: 57
# Average Training Loss for Epoch 57: 6.8716e-04; Loss1: 6.7987e-04; Loss2: 7.2894e-06
# Training Epoch: 58
# Average Training Loss for Epoch 58: 6.8713e-04; Loss1: 6.7983e-04; Loss2: 7.2976e-06
# Training Epoch: 59
# Average Training Loss for Epoch 59: 6.8708e-04; Loss1: 6.7981e-04; Loss2: 7.2727e-06
# Training Epoch: 60
# Average Training Loss for Epoch 60: 6.8705e-04; Loss1: 6.7977e-04; Loss2: 7.2876e-06
# Training Epoch: 61
# Average Training Loss for Epoch 61: 6.8704e-04; Loss1: 6.7977e-04; Loss2: 7.2667e-06
# Training Epoch: 62
# Average Training Loss for Epoch 62: 6.8701e-04; Loss1: 6.7974e-04; Loss2: 7.2753e-06
# Training Epoch: 63
# Average Training Loss for Epoch 63: 6.8705e-04; Loss1: 6.7979e-04; Loss2: 7.2540e-06
# Training Epoch: 64
# Average Training Loss for Epoch 64: 6.8707e-04; Loss1: 6.7979e-04; Loss2: 7.2781e-06
# Training Epoch: 65
# Average Training Loss for Epoch 65: 6.8738e-04; Loss1: 6.8014e-04; Loss2: 7.2369e-06
# Training Epoch: 66
# Average Training Loss for Epoch 66: 6.8798e-04; Loss1: 6.8068e-04; Loss2: 7.3043e-06
# Training Epoch: 67
# Average Training Loss for Epoch 67: 6.9013e-04; Loss1: 6.8296e-04; Loss2: 7.1707e-06
# Training Epoch: 68
# Average Training Loss for Epoch 68: 6.9350e-04; Loss1: 6.8612e-04; Loss2: 7.3743e-06
# Training Epoch: 69
# Average Training Loss for Epoch 69: 6.9665e-04; Loss1: 6.8959e-04; Loss2: 7.0656e-06
# Training Epoch: 70
# Average Training Loss for Epoch 70: 6.9589e-04; Loss1: 6.8856e-04; Loss2: 7.3217e-06
# Training Epoch: 71
# Average Training Loss for Epoch 71: 6.9263e-04; Loss1: 6.8538e-04; Loss2: 7.2525e-06
# Training Epoch: 72
# Average Training Loss for Epoch 72: 6.8989e-04; Loss1: 6.8253e-04; Loss2: 7.3522e-06
# Training Epoch: 73
# Average Training Loss for Epoch 73: 6.8841e-04; Loss1: 6.8113e-04; Loss2: 7.2771e-06
# Training Epoch: 74
# Average Training Loss for Epoch 74: 6.8752e-04; Loss1: 6.8017e-04; Loss2: 7.3540e-06
# Training Epoch: 75
# Average Training Loss for Epoch 75: 6.8718e-04; Loss1: 6.7987e-04; Loss2: 7.3151e-06
# Training Epoch: 76
# Average Training Loss for Epoch 76: 6.8690e-04; Loss1: 6.7957e-04; Loss2: 7.3228e-06
# Training Epoch: 77
# Average Training Loss for Epoch 77: 6.8681e-04; Loss1: 6.7950e-04; Loss2: 7.3151e-06
# Training Epoch: 78
# Average Training Loss for Epoch 78: 6.8670e-04; Loss1: 6.7940e-04; Loss2: 7.3014e-06
# Training Epoch: 79
# Average Training Loss for Epoch 79: 6.8667e-04; Loss1: 6.7937e-04; Loss2: 7.3049e-06
# Training Epoch: 80
# Average Training Loss for Epoch 80: 6.8663e-04; Loss1: 6.7933e-04; Loss2: 7.2913e-06
# Training Epoch: 81
# Average Training Loss for Epoch 81: 6.8662e-04; Loss1: 6.7933e-04; Loss2: 7.2952e-06
# Training Epoch: 82
# Average Training Loss for Epoch 82: 6.8660e-04; Loss1: 6.7933e-04; Loss2: 7.2725e-06
# Training Epoch: 83
# Average Training Loss for Epoch 83: 6.8662e-04; Loss1: 6.7933e-04; Loss2: 7.2880e-06
# Training Epoch: 84
# Average Training Loss for Epoch 84: 6.8663e-04; Loss1: 6.7936e-04; Loss2: 7.2729e-06
# Training Epoch: 85
# Average Training Loss for Epoch 85: 6.8670e-04; Loss1: 6.7942e-04; Loss2: 7.2799e-06
# Training Epoch: 86
# Average Training Loss for Epoch 86: 6.8678e-04; Loss1: 6.7953e-04; Loss2: 7.2529e-06
# Training Epoch: 87
# Average Training Loss for Epoch 87: 6.8692e-04; Loss1: 6.7966e-04; Loss2: 7.2577e-06
# Training Epoch: 88
# Average Training Loss for Epoch 88: 6.8716e-04; Loss1: 6.7984e-04; Loss2: 7.3238e-06
# Training Epoch: 89
# Average Training Loss for Epoch 89: 6.8752e-04; Loss1: 6.8033e-04; Loss2: 7.1927e-06
# Training Epoch: 90
# Average Training Loss for Epoch 90: 6.8830e-04; Loss1: 6.8085e-04; Loss2: 7.4461e-06
# Training Epoch: 91
# Average Training Loss for Epoch 91: 6.8964e-04; Loss1: 6.8264e-04; Loss2: 7.0020e-06
# Training Epoch: 92
# Average Training Loss for Epoch 92: 6.9166e-04; Loss1: 6.8410e-04; Loss2: 7.5551e-06
# Training Epoch: 93
# Average Training Loss for Epoch 93: 6.9333e-04; Loss1: 6.8642e-04; Loss2: 6.9132e-06
# Training Epoch: 94
# Average Training Loss for Epoch 94: 6.9384e-04; Loss1: 6.8615e-04; Loss2: 7.6866e-06
# Training Epoch: 95
# Average Training Loss for Epoch 95: 6.9336e-04; Loss1: 6.8644e-04; Loss2: 6.9221e-06
# Training Epoch: 96
# Average Training Loss for Epoch 96: 6.9150e-04; Loss1: 6.8409e-04; Loss2: 7.4096e-06
# Training Epoch: 97
# Average Training Loss for Epoch 97: 6.9001e-04; Loss1: 6.8265e-04; Loss2: 7.3625e-06
# Training Epoch: 98
# Average Training Loss for Epoch 98: 6.8843e-04; Loss1: 6.8114e-04; Loss2: 7.2939e-06
# Training Epoch: 99
# Average Training Loss for Epoch 99: 6.8762e-04; Loss1: 6.8029e-04; Loss2: 7.3268e-06
# Training Epoch: 100
# Average Training Loss for Epoch 100: 6.8692e-04; Loss1: 6.7963e-04; Loss2: 7.2921e-06
# Training Epoch: 101
# Average Training Loss for Epoch 101: 6.8657e-04; Loss1: 6.7925e-04; Loss2: 7.3202e-06
# Training Epoch: 102
# Average Training Loss for Epoch 102: 6.8613e-04; Loss1: 6.7887e-04; Loss2: 7.2639e-06
# Training Epoch: 103
# Average Training Loss for Epoch 103: 6.8600e-04; Loss1: 6.7874e-04; Loss2: 7.2587e-06
# Training Epoch: 104
# Average Training Loss for Epoch 104: 6.8586e-04; Loss1: 6.7858e-04; Loss2: 7.2836e-06
# Training Epoch: 105
# Average Training Loss for Epoch 105: 6.8583e-04; Loss1: 6.7857e-04; Loss2: 7.2662e-06
# Training Epoch: 106
# Average Training Loss for Epoch 106: 6.8578e-04; Loss1: 6.7852e-04; Loss2: 7.2522e-06
# Training Epoch: 107
# Average Training Loss for Epoch 107: 6.8577e-04; Loss1: 6.7851e-04; Loss2: 7.2628e-06
# Training Epoch: 108
# Average Training Loss for Epoch 108: 6.8574e-04; Loss1: 6.7850e-04; Loss2: 7.2380e-06
# Training Epoch: 109
# Average Training Loss for Epoch 109: 6.8573e-04; Loss1: 6.7849e-04; Loss2: 7.2455e-06
# Training Epoch: 110
# Average Training Loss for Epoch 110: 6.8572e-04; Loss1: 6.7850e-04; Loss2: 7.2239e-06
# Training Epoch: 111
# Average Training Loss for Epoch 111: 6.8571e-04; Loss1: 6.7846e-04; Loss2: 7.2480e-06
# Training Epoch: 112
# Average Training Loss for Epoch 112: 6.8571e-04; Loss1: 6.7848e-04; Loss2: 7.2285e-06
# Training Epoch: 113
# Average Training Loss for Epoch 113: 6.8573e-04; Loss1: 6.7849e-04; Loss2: 7.2390e-06
# Training Epoch: 114
# Average Training Loss for Epoch 114: 6.8595e-04; Loss1: 6.7873e-04; Loss2: 7.2234e-06
# Training Epoch: 115
# Average Training Loss for Epoch 115: 6.8665e-04; Loss1: 6.7941e-04; Loss2: 7.2351e-06
# Training Epoch: 116
# Average Training Loss for Epoch 116: 6.8923e-04; Loss1: 6.8206e-04; Loss2: 7.1672e-06
# Training Epoch: 117
# Average Training Loss for Epoch 117: 6.9326e-04; Loss1: 6.8595e-04; Loss2: 7.3051e-06
# Training Epoch: 118
# Average Training Loss for Epoch 118: 6.9546e-04; Loss1: 6.8847e-04; Loss2: 6.9956e-06
# Training Epoch: 119
# Average Training Loss for Epoch 119: 6.9296e-04; Loss1: 6.8562e-04; Loss2: 7.3410e-06
# Training Epoch: 120
# Average Training Loss for Epoch 120: 6.8944e-04; Loss1: 6.8225e-04; Loss2: 7.1816e-06
# Training Epoch: 121
# Average Training Loss for Epoch 121: 6.8721e-04; Loss1: 6.7988e-04; Loss2: 7.3394e-06
# Training Epoch: 122
# Average Training Loss for Epoch 122: 6.8628e-04; Loss1: 6.7905e-04; Loss2: 7.2283e-06
# Training Epoch: 123
# Average Training Loss for Epoch 123: 6.8572e-04; Loss1: 6.7840e-04; Loss2: 7.3191e-06
# Training Epoch: 124
# Average Training Loss for Epoch 124: 6.8554e-04; Loss1: 6.7828e-04; Loss2: 7.2635e-06
# Training Epoch: 125
# Average Training Loss for Epoch 125: 6.8537e-04; Loss1: 6.7809e-04; Loss2: 7.2747e-06
# Training Epoch: 126
# Average Training Loss for Epoch 126: 6.8532e-04; Loss1: 6.7806e-04; Loss2: 7.2594e-06
# Training Epoch: 127
# Average Training Loss for Epoch 127: 6.8525e-04; Loss1: 6.7800e-04; Loss2: 7.2578e-06
# Training Epoch: 128
# Average Training Loss for Epoch 128: 6.8523e-04; Loss1: 6.7799e-04; Loss2: 7.2467e-06
# Training Epoch: 129
# Average Training Loss for Epoch 129: 6.8520e-04; Loss1: 6.7796e-04; Loss2: 7.2463e-06
# Training Epoch: 130
# Average Training Loss for Epoch 130: 6.8519e-04; Loss1: 6.7795e-04; Loss2: 7.2417e-06
# Training Epoch: 131
# Average Training Loss for Epoch 131: 6.8518e-04; Loss1: 6.7795e-04; Loss2: 7.2294e-06
# Training Epoch: 132
# Average Training Loss for Epoch 132: 6.8518e-04; Loss1: 6.7794e-04; Loss2: 7.2392e-06
# Training Epoch: 133
# Average Training Loss for Epoch 133: 6.8529e-04; Loss1: 6.7807e-04; Loss2: 7.2227e-06
# Training Epoch: 134
# Average Training Loss for Epoch 134: 6.8553e-04; Loss1: 6.7828e-04; Loss2: 7.2448e-06
# Training Epoch: 135
# Average Training Loss for Epoch 135: 6.8652e-04; Loss1: 6.7934e-04; Loss2: 7.1749e-06
# Training Epoch: 136
# Average Training Loss for Epoch 136: 6.8848e-04; Loss1: 6.8120e-04; Loss2: 7.2725e-06
# Training Epoch: 137
# Average Training Loss for Epoch 137: 6.9160e-04; Loss1: 6.8450e-04; Loss2: 7.0966e-06
# Training Epoch: 138
# Average Training Loss for Epoch 138: 6.9347e-04; Loss1: 6.8601e-04; Loss2: 7.4514e-06
# Training Epoch: 139
# Average Training Loss for Epoch 139: 6.9205e-04; Loss1: 6.8510e-04; Loss2: 6.9474e-06
# Training Epoch: 140
# Average Training Loss for Epoch 140: 6.8916e-04; Loss1: 6.8178e-04; Loss2: 7.3833e-06
# Training Epoch: 141
# Average Training Loss for Epoch 141: 6.8722e-04; Loss1: 6.7998e-04; Loss2: 7.2387e-06
# Training Epoch: 142
# Average Training Loss for Epoch 142: 6.8601e-04; Loss1: 6.7871e-04; Loss2: 7.3073e-06
# Training Epoch: 143
# Average Training Loss for Epoch 143: 6.8551e-04; Loss1: 6.7824e-04; Loss2: 7.2651e-06
# Training Epoch: 144
# Average Training Loss for Epoch 144: 6.8514e-04; Loss1: 6.7785e-04; Loss2: 7.2893e-06
# Training Epoch: 145
# Average Training Loss for Epoch 145: 6.8503e-04; Loss1: 6.7775e-04; Loss2: 7.2747e-06
# Training Epoch: 146
# Average Training Loss for Epoch 146: 6.8490e-04; Loss1: 6.7765e-04; Loss2: 7.2578e-06
# Training Epoch: 147
# Average Training Loss for Epoch 147: 6.8487e-04; Loss1: 6.7761e-04; Loss2: 7.2581e-06
# Training Epoch: 148
# Average Training Loss for Epoch 148: 6.8481e-04; Loss1: 6.7756e-04; Loss2: 7.2525e-06
# Training Epoch: 149
# Average Training Loss for Epoch 149: 6.8481e-04; Loss1: 6.7757e-04; Loss2: 7.2462e-06
# Training Epoch: 150
# Average Training Loss for Epoch 150: 6.8479e-04; Loss1: 6.7756e-04; Loss2: 7.2296e-06
# Training Epoch: 151
# Average Training Loss for Epoch 151: 6.8473e-04; Loss1: 6.7749e-04; Loss2: 7.2403e-06
# Training Epoch: 152
# Average Training Loss for Epoch 152: 6.8467e-04; Loss1: 6.7746e-04; Loss2: 7.2034e-06
# Training Epoch: 153
# Average Training Loss for Epoch 153: 6.8464e-04; Loss1: 6.7744e-04; Loss2: 7.2056e-06
# Training Epoch: 154
# Average Training Loss for Epoch 154: 6.8461e-04; Loss1: 6.7737e-04; Loss2: 7.2407e-06
# Training Epoch: 155
# Average Training Loss for Epoch 155: 6.8458e-04; Loss1: 6.7737e-04; Loss2: 7.2150e-06
# Training Epoch: 156
# Average Training Loss for Epoch 156: 6.8458e-04; Loss1: 6.7735e-04; Loss2: 7.2327e-06
# Training Epoch: 157
# Average Training Loss for Epoch 157: 6.8458e-04; Loss1: 6.7737e-04; Loss2: 7.2101e-06
# Training Epoch: 158
# Average Training Loss for Epoch 158: 6.8484e-04; Loss1: 6.7761e-04; Loss2: 7.2304e-06
# Training Epoch: 159
# Average Training Loss for Epoch 159: 6.8554e-04; Loss1: 6.7833e-04; Loss2: 7.2037e-06
# Training Epoch: 160
# Average Training Loss for Epoch 160: 6.8786e-04; Loss1: 6.8067e-04; Loss2: 7.1923e-06
# Training Epoch: 161
# Average Training Loss for Epoch 161: 6.9117e-04; Loss1: 6.8388e-04; Loss2: 7.2966e-06
# Training Epoch: 162
# Average Training Loss for Epoch 162: 6.9234e-04; Loss1: 6.8538e-04; Loss2: 6.9668e-06
# Training Epoch: 163
# Average Training Loss for Epoch 163: 6.8995e-04; Loss1: 6.8253e-04; Loss2: 7.4168e-06
# Training Epoch: 164
# Average Training Loss for Epoch 164: 6.8723e-04; Loss1: 6.8008e-04; Loss2: 7.1426e-06
# Training Epoch: 165
# Average Training Loss for Epoch 165: 6.8563e-04; Loss1: 6.7830e-04; Loss2: 7.3286e-06
# Training Epoch: 166
# Average Training Loss for Epoch 166: 6.8491e-04; Loss1: 6.7770e-04; Loss2: 7.2032e-06
# Training Epoch: 167
# Average Training Loss for Epoch 167: 6.8449e-04; Loss1: 6.7719e-04; Loss2: 7.2983e-06
# Training Epoch: 168
# Average Training Loss for Epoch 168: 6.8435e-04; Loss1: 6.7711e-04; Loss2: 7.2428e-06
# Training Epoch: 169
# Average Training Loss for Epoch 169: 6.8422e-04; Loss1: 6.7696e-04; Loss2: 7.2571e-06
# Training Epoch: 170
# Average Training Loss for Epoch 170: 6.8418e-04; Loss1: 6.7694e-04; Loss2: 7.2339e-06
# Training Epoch: 171
# Average Training Loss for Epoch 171: 6.8413e-04; Loss1: 6.7689e-04; Loss2: 7.2358e-06
# Training Epoch: 172
# Average Training Loss for Epoch 172: 6.8411e-04; Loss1: 6.7688e-04; Loss2: 7.2302e-06
# Training Epoch: 173
# Average Training Loss for Epoch 173: 6.8408e-04; Loss1: 6.7686e-04; Loss2: 7.2224e-06
# Training Epoch: 174
# Average Training Loss for Epoch 174: 6.8407e-04; Loss1: 6.7685e-04; Loss2: 7.2215e-06
# Training Epoch: 175
# Average Training Loss for Epoch 175: 6.8405e-04; Loss1: 6.7685e-04; Loss2: 7.2080e-06
# Training Epoch: 176
# Average Training Loss for Epoch 176: 6.8404e-04; Loss1: 6.7683e-04; Loss2: 7.2139e-06
# Training Epoch: 177
# Average Training Loss for Epoch 177: 6.8406e-04; Loss1: 6.7685e-04; Loss2: 7.2104e-06
# Training Epoch: 178
# Average Training Loss for Epoch 178: 6.8412e-04; Loss1: 6.7691e-04; Loss2: 7.2115e-06
# Training Epoch: 179
# Average Training Loss for Epoch 179: 6.8447e-04; Loss1: 6.7729e-04; Loss2: 7.1807e-06
# Training Epoch: 180
# Average Training Loss for Epoch 180: 6.8540e-04; Loss1: 6.7816e-04; Loss2: 7.2421e-06
# Training Epoch: 181
# Average Training Loss for Epoch 181: 6.8787e-04; Loss1: 6.8078e-04; Loss2: 7.0871e-06
# Training Epoch: 182
# Average Training Loss for Epoch 182: 6.9075e-04; Loss1: 6.8346e-04; Loss2: 7.2951e-06
# Training Epoch: 183
# Average Training Loss for Epoch 183: 6.9121e-04; Loss1: 6.8411e-04; Loss2: 7.0982e-06
# Training Epoch: 184
# Average Training Loss for Epoch 184: 6.8909e-04; Loss1: 6.8171e-04; Loss2: 7.3808e-06
# Training Epoch: 185
# Average Training Loss for Epoch 185: 6.8698e-04; Loss1: 6.7992e-04; Loss2: 7.0606e-06
# Training Epoch: 186
# Average Training Loss for Epoch 186: 6.8539e-04; Loss1: 6.7808e-04; Loss2: 7.3118e-06
# Training Epoch: 187
# Average Training Loss for Epoch 187: 6.8465e-04; Loss1: 6.7748e-04; Loss2: 7.1749e-06
# Training Epoch: 188
# Average Training Loss for Epoch 188: 6.8414e-04; Loss1: 6.7685e-04; Loss2: 7.2933e-06
# Training Epoch: 189
# Average Training Loss for Epoch 189: 6.8399e-04; Loss1: 6.7678e-04; Loss2: 7.2019e-06
# Training Epoch: 190
# Average Training Loss for Epoch 190: 6.8382e-04; Loss1: 6.7656e-04; Loss2: 7.2589e-06
# Training Epoch: 191
# Average Training Loss for Epoch 191: 6.8380e-04; Loss1: 6.7658e-04; Loss2: 7.2163e-06
# Training Epoch: 192
# Average Training Loss for Epoch 192: 6.8373e-04; Loss1: 6.7650e-04; Loss2: 7.2307e-06
# Training Epoch: 193
# Average Training Loss for Epoch 193: 6.8375e-04; Loss1: 6.7654e-04; Loss2: 7.2052e-06
# Training Epoch: 194
# Average Training Loss for Epoch 194: 6.8373e-04; Loss1: 6.7651e-04; Loss2: 7.2187e-06
# Training Epoch: 195
# Average Training Loss for Epoch 195: 6.8380e-04; Loss1: 6.7660e-04; Loss2: 7.2010e-06
# Training Epoch: 196
# Average Training Loss for Epoch 196: 6.8385e-04; Loss1: 6.7664e-04; Loss2: 7.2120e-06
# Training Epoch: 197
# Average Training Loss for Epoch 197: 6.8406e-04; Loss1: 6.7689e-04; Loss2: 7.1711e-06
# Training Epoch: 198
# Average Training Loss for Epoch 198: 6.8439e-04; Loss1: 6.7711e-04; Loss2: 7.2853e-06
# Training Epoch: 199
# Average Training Loss for Epoch 199: 6.8533e-04; Loss1: 6.7825e-04; Loss2: 7.0789e-06
# Training Epoch: 200
# Average Training Loss for Epoch 200: 6.8648e-04; Loss1: 6.7918e-04; Loss2: 7.2997e-06
# Training Epoch: 201
# Average Training Loss for Epoch 201: 6.8792e-04; Loss1: 6.8081e-04; Loss2: 7.1169e-06
# Training Epoch: 202
# Average Training Loss for Epoch 202: 6.8738e-04; Loss1: 6.7997e-04; Loss2: 7.4149e-06
# Training Epoch: 203
# Average Training Loss for Epoch 203: 6.8619e-04; Loss1: 6.7929e-04; Loss2: 6.8968e-06
# Training Epoch: 204
# Average Training Loss for Epoch 204: 6.8492e-04; Loss1: 6.7758e-04; Loss2: 7.3456e-06
# Training Epoch: 205
# Average Training Loss for Epoch 205: 6.8430e-04; Loss1: 6.7720e-04; Loss2: 7.0925e-06
# Training Epoch: 206
# Average Training Loss for Epoch 206: 6.8382e-04; Loss1: 6.7653e-04; Loss2: 7.2867e-06
# Training Epoch: 207
# Average Training Loss for Epoch 207: 6.8364e-04; Loss1: 6.7644e-04; Loss2: 7.2072e-06
# Training Epoch: 208
# Average Training Loss for Epoch 208: 6.8348e-04; Loss1: 6.7623e-04; Loss2: 7.2497e-06
# Training Epoch: 209
# Average Training Loss for Epoch 209: 6.8347e-04; Loss1: 6.7627e-04; Loss2: 7.1992e-06
# Training Epoch: 210
# Average Training Loss for Epoch 210: 6.8343e-04; Loss1: 6.7620e-04; Loss2: 7.2305e-06
# Training Epoch: 211
# Average Training Loss for Epoch 211: 6.8350e-04; Loss1: 6.7631e-04; Loss2: 7.1870e-06
# Training Epoch: 212
# Average Training Loss for Epoch 212: 6.8356e-04; Loss1: 6.7633e-04; Loss2: 7.2339e-06
# Training Epoch: 213
# Average Training Loss for Epoch 213: 6.8379e-04; Loss1: 6.7662e-04; Loss2: 7.1727e-06
# Training Epoch: 214
# Average Training Loss for Epoch 214: 6.8407e-04; Loss1: 6.7682e-04; Loss2: 7.2472e-06
# Training Epoch: 215
# Average Training Loss for Epoch 215: 6.8462e-04; Loss1: 6.7748e-04; Loss2: 7.1397e-06
# Training Epoch: 216
# Average Training Loss for Epoch 216: 6.8522e-04; Loss1: 6.7794e-04; Loss2: 7.2798e-06
# Training Epoch: 217
# Average Training Loss for Epoch 217: 6.8577e-04; Loss1: 6.7868e-04; Loss2: 7.0878e-06
# Training Epoch: 218
# Average Training Loss for Epoch 218: 6.8594e-04; Loss1: 6.7864e-04; Loss2: 7.2980e-06
# Training Epoch: 219
# Average Training Loss for Epoch 219: 6.8569e-04; Loss1: 6.7857e-04; Loss2: 7.1120e-06
# Training Epoch: 220
# Average Training Loss for Epoch 220: 6.8512e-04; Loss1: 6.7782e-04; Loss2: 7.2982e-06
# Training Epoch: 221
# Average Training Loss for Epoch 221: 6.8456e-04; Loss1: 6.7744e-04; Loss2: 7.1283e-06
# Training Epoch: 222
# Average Training Loss for Epoch 222: 6.8407e-04; Loss1: 6.7678e-04; Loss2: 7.2909e-06
# Training Epoch: 223
# Average Training Loss for Epoch 223: 6.8381e-04; Loss1: 6.7664e-04; Loss2: 7.1629e-06
# Training Epoch: 224
# Average Training Loss for Epoch 224: 6.8355e-04; Loss1: 6.7629e-04; Loss2: 7.2590e-06
# Training Epoch: 225
# Average Training Loss for Epoch 225: 6.8349e-04; Loss1: 6.7630e-04; Loss2: 7.1811e-06
# Training Epoch: 226
# Average Training Loss for Epoch 226: 6.8338e-04; Loss1: 6.7614e-04; Loss2: 7.2458e-06
# Training Epoch: 227
# Average Training Loss for Epoch 227: 6.8343e-04; Loss1: 6.7626e-04; Loss2: 7.1763e-06
# Training Epoch: 228
# Average Training Loss for Epoch 228: 6.8344e-04; Loss1: 6.7620e-04; Loss2: 7.2388e-06
# Training Epoch: 229
# Average Training Loss for Epoch 229: 6.8361e-04; Loss1: 6.7645e-04; Loss2: 7.1661e-06
# Training Epoch: 230
# Average Training Loss for Epoch 230: 6.8376e-04; Loss1: 6.7654e-04; Loss2: 7.2234e-06
# Training Epoch: 231
# Average Training Loss for Epoch 231: 6.8414e-04; Loss1: 6.7699e-04; Loss2: 7.1549e-06
# Training Epoch: 232
# Average Training Loss for Epoch 232: 6.8445e-04; Loss1: 6.7717e-04; Loss2: 7.2810e-06
# Training Epoch: 233
# Average Training Loss for Epoch 233: 6.8492e-04; Loss1: 6.7781e-04; Loss2: 7.1167e-06
# Training Epoch: 234
# Average Training Loss for Epoch 234: 6.8519e-04; Loss1: 6.7773e-04; Loss2: 7.4550e-06
# Training Epoch: 235
# Average Training Loss for Epoch 235: 6.8518e-04; Loss1: 6.7817e-04; Loss2: 7.0077e-06
# Training Epoch: 236
# Average Training Loss for Epoch 236: 6.8473e-04; Loss1: 6.7735e-04; Loss2: 7.3765e-06
# Training Epoch: 237
# Average Training Loss for Epoch 237: 6.8432e-04; Loss1: 6.7717e-04; Loss2: 7.1537e-06
# Training Epoch: 238
# Average Training Loss for Epoch 238: 6.8393e-04; Loss1: 6.7665e-04; Loss2: 7.2839e-06
# Training Epoch: 239
# Average Training Loss for Epoch 239: 6.8367e-04; Loss1: 6.7651e-04; Loss2: 7.1581e-06
# Training Epoch: 240
# Average Training Loss for Epoch 240: 6.8345e-04; Loss1: 6.7616e-04; Loss2: 7.2856e-06
# Training Epoch: 241
# Average Training Loss for Epoch 241: 6.8336e-04; Loss1: 6.7619e-04; Loss2: 7.1702e-06
# Training Epoch: 242
# Average Training Loss for Epoch 242: 6.8328e-04; Loss1: 6.7603e-04; Loss2: 7.2485e-06
# Training Epoch: 243
# Average Training Loss for Epoch 243: 6.8332e-04; Loss1: 6.7615e-04; Loss2: 7.1677e-06
# Training Epoch: 244
# Average Training Loss for Epoch 244: 6.8335e-04; Loss1: 6.7608e-04; Loss2: 7.2724e-06
# Training Epoch: 245
# Average Training Loss for Epoch 245: 6.8353e-04; Loss1: 6.7637e-04; Loss2: 7.1557e-06
# Training Epoch: 246
# Average Training Loss for Epoch 246: 6.8370e-04; Loss1: 6.7635e-04; Loss2: 7.3462e-06
# Training Epoch: 247
# Average Training Loss for Epoch 247: 6.8398e-04; Loss1: 6.7696e-04; Loss2: 7.0239e-06
# Training Epoch: 248
# Average Training Loss for Epoch 248: 6.8408e-04; Loss1: 6.7676e-04; Loss2: 7.3122e-06
# Training Epoch: 249
# Average Training Loss for Epoch 249: 6.8425e-04; Loss1: 6.7711e-04; Loss2: 7.1458e-06
# Training Epoch: 250
# Average Training Loss for Epoch 250: 6.8427e-04; Loss1: 6.7694e-04; Loss2: 7.3276e-06
# Training Epoch: 251
# Average Training Loss for Epoch 251: 6.8408e-04; Loss1: 6.7697e-04; Loss2: 7.1114e-06
# Training Epoch: 252
# Average Training Loss for Epoch 252: 6.8335e-04; Loss1: 6.7605e-04; Loss2: 7.3023e-06
# Training Epoch: 253
# Average Training Loss for Epoch 253: 6.8296e-04; Loss1: 6.7592e-04; Loss2: 7.0328e-06
# Training Epoch: 254
# Average Training Loss for Epoch 254: 6.8263e-04; Loss1: 6.7531e-04; Loss2: 7.3185e-06
# Training Epoch: 255
# Average Training Loss for Epoch 255: 6.8253e-04; Loss1: 6.7539e-04; Loss2: 7.1441e-06
# Training Epoch: 256
# Average Training Loss for Epoch 256: 6.8242e-04; Loss1: 6.7518e-04; Loss2: 7.2331e-06
# Training Epoch: 257
# Average Training Loss for Epoch 257: 6.8240e-04; Loss1: 6.7526e-04; Loss2: 7.1403e-06
# Training Epoch: 258
# Average Training Loss for Epoch 258: 6.8235e-04; Loss1: 6.7511e-04; Loss2: 7.2360e-06
# Training Epoch: 259
# Average Training Loss for Epoch 259: 6.8243e-04; Loss1: 6.7528e-04; Loss2: 7.1500e-06
# Training Epoch: 260
# Average Training Loss for Epoch 260: 6.8245e-04; Loss1: 6.7523e-04; Loss2: 7.2230e-06
# Training Epoch: 261
# Average Training Loss for Epoch 261: 6.8265e-04; Loss1: 6.7552e-04; Loss2: 7.1358e-06
# Training Epoch: 262
# Average Training Loss for Epoch 262: 6.8284e-04; Loss1: 6.7561e-04; Loss2: 7.2267e-06
# Training Epoch: 263
# Average Training Loss for Epoch 263: 6.8325e-04; Loss1: 6.7615e-04; Loss2: 7.1039e-06
# Training Epoch: 264
# Average Training Loss for Epoch 264: 6.8367e-04; Loss1: 6.7636e-04; Loss2: 7.3168e-06
# Training Epoch: 265
# Average Training Loss for Epoch 265: 6.8420e-04; Loss1: 6.7708e-04; Loss2: 7.1167e-06
# Training Epoch: 266
# Average Training Loss for Epoch 266: 6.8432e-04; Loss1: 6.7700e-04; Loss2: 7.3177e-06
# Training Epoch: 267
# Average Training Loss for Epoch 267: 6.8420e-04; Loss1: 6.7713e-04; Loss2: 7.0701e-06
# Training Epoch: 268
# Average Training Loss for Epoch 268: 6.8375e-04; Loss1: 6.7644e-04; Loss2: 7.3023e-06
# Training Epoch: 269
# Average Training Loss for Epoch 269: 6.8331e-04; Loss1: 6.7622e-04; Loss2: 7.0887e-06
# Training Epoch: 270
# Average Training Loss for Epoch 270: 6.8291e-04; Loss1: 6.7562e-04; Loss2: 7.2906e-06
# Training Epoch: 271
# Average Training Loss for Epoch 271: 6.8265e-04; Loss1: 6.7554e-04; Loss2: 7.1103e-06
# Training Epoch: 272
# Average Training Loss for Epoch 272: 6.8242e-04; Loss1: 6.7516e-04; Loss2: 7.2606e-06
# Training Epoch: 273
# Average Training Loss for Epoch 273: 6.8235e-04; Loss1: 6.7521e-04; Loss2: 7.1340e-06
# Training Epoch: 274
# Average Training Loss for Epoch 274: 6.8225e-04; Loss1: 6.7500e-04; Loss2: 7.2563e-06
# Training Epoch: 275
# Average Training Loss for Epoch 275: 6.8229e-04; Loss1: 6.7516e-04; Loss2: 7.1323e-06
# Training Epoch: 276
# Average Training Loss for Epoch 276: 6.8230e-04; Loss1: 6.7508e-04; Loss2: 7.2261e-06
# Training Epoch: 277
# Average Training Loss for Epoch 277: 6.8241e-04; Loss1: 6.7529e-04; Loss2: 7.1178e-06
# Training Epoch: 278
# Average Training Loss for Epoch 278: 6.8249e-04; Loss1: 6.7525e-04; Loss2: 7.2399e-06
# Training Epoch: 279
# Average Training Loss for Epoch 279: 6.8276e-04; Loss1: 6.7564e-04; Loss2: 7.1121e-06
# Training Epoch: 280
# Average Training Loss for Epoch 280: 6.8297e-04; Loss1: 6.7572e-04; Loss2: 7.2580e-06
# Training Epoch: 281
# Average Training Loss for Epoch 281: 6.8333e-04; Loss1: 6.7624e-04; Loss2: 7.0859e-06
# Training Epoch: 282
# Average Training Loss for Epoch 282: 6.8352e-04; Loss1: 6.7616e-04; Loss2: 7.3677e-06
# Training Epoch: 283
# Average Training Loss for Epoch 283: 6.8355e-04; Loss1: 6.7647e-04; Loss2: 7.0837e-06
# Training Epoch: 284
# Average Training Loss for Epoch 284: 6.8342e-04; Loss1: 6.7615e-04; Loss2: 7.2761e-06
# Training Epoch: 285
# Average Training Loss for Epoch 285: 6.8317e-04; Loss1: 6.7606e-04; Loss2: 7.1063e-06
# Training Epoch: 286
# Average Training Loss for Epoch 286: 6.8289e-04; Loss1: 6.7564e-04; Loss2: 7.2507e-06
# Training Epoch: 287
# Average Training Loss for Epoch 287: 6.8259e-04; Loss1: 6.7548e-04; Loss2: 7.1138e-06
# Training Epoch: 288
# Average Training Loss for Epoch 288: 6.8235e-04; Loss1: 6.7506e-04; Loss2: 7.2928e-06
# Training Epoch: 289
# Average Training Loss for Epoch 289: 6.8225e-04; Loss1: 6.7513e-04; Loss2: 7.1173e-06
# Training Epoch: 290
# Average Training Loss for Epoch 290: 6.8213e-04; Loss1: 6.7488e-04; Loss2: 7.2547e-06
# Training Epoch: 291
# Average Training Loss for Epoch 291: 6.8212e-04; Loss1: 6.7501e-04; Loss2: 7.1162e-06
# Training Epoch: 292
# Average Training Loss for Epoch 292: 6.8210e-04; Loss1: 6.7487e-04; Loss2: 7.2313e-06
# Training Epoch: 293
# Average Training Loss for Epoch 293: 6.8217e-04; Loss1: 6.7506e-04; Loss2: 7.1190e-06
# Training Epoch: 294
# Average Training Loss for Epoch 294: 6.8223e-04; Loss1: 6.7493e-04; Loss2: 7.2960e-06
# Training Epoch: 295
# Average Training Loss for Epoch 295: 6.8243e-04; Loss1: 6.7541e-04; Loss2: 7.0220e-06
# Training Epoch: 296
# Average Training Loss for Epoch 296: 6.8246e-04; Loss1: 6.7516e-04; Loss2: 7.2993e-06
# Training Epoch: 297
# Average Training Loss for Epoch 297: 6.8265e-04; Loss1: 6.7555e-04; Loss2: 7.1018e-06
# Training Epoch: 298
# Average Training Loss for Epoch 298: 6.8276e-04; Loss1: 6.7548e-04; Loss2: 7.2817e-06
# Training Epoch: 299
# Average Training Loss for Epoch 299: 6.8291e-04; Loss1: 6.7584e-04; Loss2: 7.0660e-06
# Training Epoch: 300
# Average Training Loss for Epoch 300: 6.8290e-04; Loss1: 6.7563e-04; Loss2: 7.2760e-06
# Training Epoch: 301
# Average Training Loss for Epoch 301: 6.8275e-04; Loss1: 6.7568e-04; Loss2: 7.0693e-06
# Training Epoch: 302
# Average Training Loss for Epoch 302: 6.8216e-04; Loss1: 6.7483e-04; Loss2: 7.3281e-06
# Training Epoch: 303
# Average Training Loss for Epoch 303: 6.8178e-04; Loss1: 6.7475e-04; Loss2: 7.0318e-06
# Training Epoch: 304
# Average Training Loss for Epoch 304: 6.8151e-04; Loss1: 6.7422e-04; Loss2: 7.2854e-06
# Training Epoch: 305
# Average Training Loss for Epoch 305: 6.8141e-04; Loss1: 6.7428e-04; Loss2: 7.1305e-06
# Training Epoch: 306
# Average Training Loss for Epoch 306: 6.8132e-04; Loss1: 6.7410e-04; Loss2: 7.2150e-06
# Training Epoch: 307
# Average Training Loss for Epoch 307: 6.8129e-04; Loss1: 6.7417e-04; Loss2: 7.1269e-06
# Training Epoch: 308
# Average Training Loss for Epoch 308: 6.8125e-04; Loss1: 6.7404e-04; Loss2: 7.2149e-06
# Training Epoch: 309
# Average Training Loss for Epoch 309: 6.8130e-04; Loss1: 6.7417e-04; Loss2: 7.1366e-06
# Training Epoch: 310
# Average Training Loss for Epoch 310: 6.8133e-04; Loss1: 6.7413e-04; Loss2: 7.1989e-06
# Training Epoch: 311
# Average Training Loss for Epoch 311: 6.8144e-04; Loss1: 6.7433e-04; Loss2: 7.1140e-06
# Training Epoch: 312
# Average Training Loss for Epoch 312: 6.8157e-04; Loss1: 6.7437e-04; Loss2: 7.2044e-06
# Training Epoch: 313
# Average Training Loss for Epoch 313: 6.8190e-04; Loss1: 6.7478e-04; Loss2: 7.1169e-06
# Training Epoch: 314
# Average Training Loss for Epoch 314: 6.8224e-04; Loss1: 6.7499e-04; Loss2: 7.2547e-06
# Training Epoch: 315
# Average Training Loss for Epoch 315: 6.8270e-04; Loss1: 6.7562e-04; Loss2: 7.0741e-06
# Training Epoch: 316
# Average Training Loss for Epoch 316: 6.8292e-04; Loss1: 6.7563e-04; Loss2: 7.2842e-06
# Training Epoch: 317
# Average Training Loss for Epoch 317: 6.8286e-04; Loss1: 6.7584e-04; Loss2: 7.0153e-06
# Training Epoch: 318
# Average Training Loss for Epoch 318: 6.8253e-04; Loss1: 6.7522e-04; Loss2: 7.3016e-06
# Training Epoch: 319
# Average Training Loss for Epoch 319: 6.8214e-04; Loss1: 6.7510e-04; Loss2: 7.0435e-06
# Training Epoch: 320
# Average Training Loss for Epoch 320: 6.8181e-04; Loss1: 6.7450e-04; Loss2: 7.3061e-06
# Training Epoch: 321
# Average Training Loss for Epoch 321: 6.8151e-04; Loss1: 6.7442e-04; Loss2: 7.0914e-06
# Training Epoch: 322
# Average Training Loss for Epoch 322: 6.8132e-04; Loss1: 6.7406e-04; Loss2: 7.2597e-06
# Training Epoch: 323
# Average Training Loss for Epoch 323: 6.8122e-04; Loss1: 6.7411e-04; Loss2: 7.1090e-06
# Training Epoch: 324
# Average Training Loss for Epoch 324: 6.8113e-04; Loss1: 6.7389e-04; Loss2: 7.2319e-06
# Training Epoch: 325
# Average Training Loss for Epoch 325: 6.8113e-04; Loss1: 6.7401e-04; Loss2: 7.1165e-06
# Training Epoch: 326
# Average Training Loss for Epoch 326: 6.8112e-04; Loss1: 6.7389e-04; Loss2: 7.2263e-06
# Training Epoch: 327
# Average Training Loss for Epoch 327: 6.8117e-04; Loss1: 6.7407e-04; Loss2: 7.1076e-06
# Training Epoch: 328
# Average Training Loss for Epoch 328: 6.8123e-04; Loss1: 6.7400e-04; Loss2: 7.2350e-06
# Training Epoch: 329
# Average Training Loss for Epoch 329: 6.8141e-04; Loss1: 6.7431e-04; Loss2: 7.0984e-06
# Training Epoch: 330
# Average Training Loss for Epoch 330: 6.8159e-04; Loss1: 6.7436e-04; Loss2: 7.2303e-06
# Training Epoch: 331
# Average Training Loss for Epoch 331: 6.8188e-04; Loss1: 6.7482e-04; Loss2: 7.0686e-06
# Training Epoch: 332
# Average Training Loss for Epoch 332: 6.8215e-04; Loss1: 6.7491e-04; Loss2: 7.2394e-06
# Training Epoch: 333
# Average Training Loss for Epoch 333: 6.8230e-04; Loss1: 6.7524e-04; Loss2: 7.0649e-06
# Training Epoch: 334
# Average Training Loss for Epoch 334: 6.8224e-04; Loss1: 6.7495e-04; Loss2: 7.2966e-06
# Training Epoch: 335
# Average Training Loss for Epoch 335: 6.8204e-04; Loss1: 6.7500e-04; Loss2: 7.0379e-06
# Training Epoch: 336
# Average Training Loss for Epoch 336: 6.8177e-04; Loss1: 6.7445e-04; Loss2: 7.3193e-06
# Training Epoch: 337
# Average Training Loss for Epoch 337: 6.8147e-04; Loss1: 6.7439e-04; Loss2: 7.0790e-06
# Training Epoch: 338
# Average Training Loss for Epoch 338: 6.8125e-04; Loss1: 6.7397e-04; Loss2: 7.2817e-06
# Training Epoch: 339
# Average Training Loss for Epoch 339: 6.8112e-04; Loss1: 6.7402e-04; Loss2: 7.0944e-06
# Training Epoch: 340
# Average Training Loss for Epoch 340: 6.8102e-04; Loss1: 6.7377e-04; Loss2: 7.2422e-06
# Training Epoch: 341
# Average Training Loss for Epoch 341: 6.8096e-04; Loss1: 6.7386e-04; Loss2: 7.0937e-06
# Training Epoch: 342
# Average Training Loss for Epoch 342: 6.8091e-04; Loss1: 6.7367e-04; Loss2: 7.2339e-06
# Training Epoch: 343
# Average Training Loss for Epoch 343: 6.8095e-04; Loss1: 6.7385e-04; Loss2: 7.1031e-06
# Training Epoch: 344
# Average Training Loss for Epoch 344: 6.8099e-04; Loss1: 6.7374e-04; Loss2: 7.2447e-06
# Training Epoch: 345
# Average Training Loss for Epoch 345: 6.8111e-04; Loss1: 6.7402e-04; Loss2: 7.0906e-06
# Training Epoch: 346
# Average Training Loss for Epoch 346: 6.8123e-04; Loss1: 6.7399e-04; Loss2: 7.2416e-06
# Training Epoch: 347
# Average Training Loss for Epoch 347: 6.8139e-04; Loss1: 6.7433e-04; Loss2: 7.0580e-06
# Training Epoch: 348
# Average Training Loss for Epoch 348: 6.8162e-04; Loss1: 6.7433e-04; Loss2: 7.2881e-06
# Training Epoch: 349
# Average Training Loss for Epoch 349: 6.8178e-04; Loss1: 6.7479e-04; Loss2: 6.9819e-06
# Training Epoch: 350
# Average Training Loss for Epoch 350: 6.8171e-04; Loss1: 6.7436e-04; Loss2: 7.3465e-06
# Training Epoch: 351
# Average Training Loss for Epoch 351: 6.8149e-04; Loss1: 6.7447e-04; Loss2: 7.0220e-06
# Training Epoch: 352
# Average Training Loss for Epoch 352: 6.8090e-04; Loss1: 6.7358e-04; Loss2: 7.3197e-06
# Training Epoch: 353
# Average Training Loss for Epoch 353: 6.8060e-04; Loss1: 6.7351e-04; Loss2: 7.0904e-06
# Training Epoch: 354
# Average Training Loss for Epoch 354: 6.8043e-04; Loss1: 6.7317e-04; Loss2: 7.2594e-06
# Training Epoch: 355
# Average Training Loss for Epoch 355: 6.8033e-04; Loss1: 6.7320e-04; Loss2: 7.1305e-06
# Training Epoch: 356
# Average Training Loss for Epoch 356: 6.8027e-04; Loss1: 6.7303e-04; Loss2: 7.2411e-06
# Training Epoch: 357
# Average Training Loss for Epoch 357: 6.8024e-04; Loss1: 6.7309e-04; Loss2: 7.1477e-06
# Training Epoch: 358
# Average Training Loss for Epoch 358: 6.8023e-04; Loss1: 6.7296e-04; Loss2: 7.2687e-06
# Training Epoch: 359
# Average Training Loss for Epoch 359: 6.8026e-04; Loss1: 6.7311e-04; Loss2: 7.1534e-06
# Training Epoch: 360
# Average Training Loss for Epoch 360: 6.8035e-04; Loss1: 6.7302e-04; Loss2: 7.3314e-06
# Training Epoch: 361
# Average Training Loss for Epoch 361: 6.8047e-04; Loss1: 6.7349e-04; Loss2: 6.9813e-06
# Training Epoch: 362
# Average Training Loss for Epoch 362: 6.8064e-04; Loss1: 6.7325e-04; Loss2: 7.3882e-06
# Training Epoch: 363
# Average Training Loss for Epoch 363: 6.8092e-04; Loss1: 6.7397e-04; Loss2: 6.9428e-06
# Training Epoch: 364
# Average Training Loss for Epoch 364: 6.8120e-04; Loss1: 6.7372e-04; Loss2: 7.4759e-06
# Training Epoch: 365
# Average Training Loss for Epoch 365: 6.8141e-04; Loss1: 6.7446e-04; Loss2: 6.9482e-06
# Training Epoch: 366
# Average Training Loss for Epoch 366: 6.8155e-04; Loss1: 6.7412e-04; Loss2: 7.4274e-06
# Training Epoch: 367
# Average Training Loss for Epoch 367: 6.8135e-04; Loss1: 6.7443e-04; Loss2: 6.9169e-06
# Training Epoch: 368
# Average Training Loss for Epoch 368: 6.8113e-04; Loss1: 6.7371e-04; Loss2: 7.4111e-06
# Training Epoch: 369
# Average Training Loss for Epoch 369: 6.8076e-04; Loss1: 6.7387e-04; Loss2: 6.8883e-06
# Training Epoch: 370
# Average Training Loss for Epoch 370: 6.8051e-04; Loss1: 6.7308e-04; Loss2: 7.4239e-06
# Training Epoch: 371
# Average Training Loss for Epoch 371: 6.8029e-04; Loss1: 6.7329e-04; Loss2: 6.9973e-06
# Training Epoch: 372
# Average Training Loss for Epoch 372: 6.8020e-04; Loss1: 6.7285e-04; Loss2: 7.3439e-06
# Training Epoch: 373
# Average Training Loss for Epoch 373: 6.8009e-04; Loss1: 6.7306e-04; Loss2: 7.0222e-06
# Training Epoch: 374
# Average Training Loss for Epoch 374: 6.8007e-04; Loss1: 6.7276e-04; Loss2: 7.3127e-06
# Training Epoch: 375
# Average Training Loss for Epoch 375: 6.8003e-04; Loss1: 6.7300e-04; Loss2: 7.0325e-06
# Training Epoch: 376
# Average Training Loss for Epoch 376: 6.8007e-04; Loss1: 6.7275e-04; Loss2: 7.3191e-06
# Training Epoch: 377
# Average Training Loss for Epoch 377: 6.8011e-04; Loss1: 6.7308e-04; Loss2: 7.0329e-06
# Training Epoch: 378
# Average Training Loss for Epoch 378: 6.8024e-04; Loss1: 6.7294e-04; Loss2: 7.3060e-06
# Training Epoch: 379
# Average Training Loss for Epoch 379: 6.8033e-04; Loss1: 6.7333e-04; Loss2: 6.9996e-06
# Training Epoch: 380
# Average Training Loss for Epoch 380: 6.8055e-04; Loss1: 6.7317e-04; Loss2: 7.3726e-06
# Training Epoch: 381
# Average Training Loss for Epoch 381: 6.8073e-04; Loss1: 6.7383e-04; Loss2: 6.9034e-06
# Training Epoch: 382
# Average Training Loss for Epoch 382: 6.8087e-04; Loss1: 6.7340e-04; Loss2: 7.4739e-06
# Training Epoch: 383
# Average Training Loss for Epoch 383: 6.8082e-04; Loss1: 6.7387e-04; Loss2: 6.9469e-06
# Training Epoch: 384
# Average Training Loss for Epoch 384: 6.8081e-04; Loss1: 6.7339e-04; Loss2: 7.4202e-06
# Training Epoch: 385
# Average Training Loss for Epoch 385: 6.8055e-04; Loss1: 6.7363e-04; Loss2: 6.9245e-06
# Training Epoch: 386
# Average Training Loss for Epoch 386: 6.8042e-04; Loss1: 6.7302e-04; Loss2: 7.3966e-06
# Training Epoch: 387
# Average Training Loss for Epoch 387: 6.8021e-04; Loss1: 6.7325e-04; Loss2: 6.9593e-06
# Training Epoch: 388
# Average Training Loss for Epoch 388: 6.8013e-04; Loss1: 6.7277e-04; Loss2: 7.3624e-06
# Training Epoch: 389
# Average Training Loss for Epoch 389: 6.7999e-04; Loss1: 6.7305e-04; Loss2: 6.9409e-06
# Training Epoch: 390
# Average Training Loss for Epoch 390: 6.7992e-04; Loss1: 6.7255e-04; Loss2: 7.3664e-06
# Training Epoch: 391
# Average Training Loss for Epoch 391: 6.7986e-04; Loss1: 6.7285e-04; Loss2: 7.0041e-06
# Training Epoch: 392
# Average Training Loss for Epoch 392: 6.7990e-04; Loss1: 6.7256e-04; Loss2: 7.3357e-06
# Training Epoch: 393
# Average Training Loss for Epoch 393: 6.7988e-04; Loss1: 6.7288e-04; Loss2: 7.0016e-06
# Training Epoch: 394
# Average Training Loss for Epoch 394: 6.7997e-04; Loss1: 6.7262e-04; Loss2: 7.3455e-06
# Training Epoch: 395
# Average Training Loss for Epoch 395: 6.8002e-04; Loss1: 6.7303e-04; Loss2: 6.9894e-06
# Training Epoch: 396
# Average Training Loss for Epoch 396: 6.8017e-04; Loss1: 6.7280e-04; Loss2: 7.3647e-06
# Training Epoch: 397
# Average Training Loss for Epoch 397: 6.8024e-04; Loss1: 6.7327e-04; Loss2: 6.9604e-06
# Training Epoch: 398
# Average Training Loss for Epoch 398: 6.8041e-04; Loss1: 6.7305e-04; Loss2: 7.3575e-06
# Training Epoch: 399
# Average Training Loss for Epoch 399: 6.8040e-04; Loss1: 6.7352e-04; Loss2: 6.8803e-06
# Training Epoch: 400
# Average Training Loss for Epoch 400: 6.8037e-04; Loss1: 6.7293e-04; Loss2: 7.4374e-06
# Training Epoch: 401
# Average Training Loss for Epoch 401: 6.8012e-04; Loss1: 6.7318e-04; Loss2: 6.9331e-06
# Training Epoch: 402
# Average Training Loss for Epoch 402: 6.7975e-04; Loss1: 6.7237e-04; Loss2: 7.3813e-06
# Training Epoch: 403
# Average Training Loss for Epoch 403: 6.7948e-04; Loss1: 6.7252e-04; Loss2: 6.9618e-06
# Training Epoch: 404
# Average Training Loss for Epoch 404: 6.7938e-04; Loss1: 6.7206e-04; Loss2: 7.3231e-06
# Training Epoch: 405
# Average Training Loss for Epoch 405: 6.7927e-04; Loss1: 6.7223e-04; Loss2: 7.0445e-06
# Training Epoch: 406
# Average Training Loss for Epoch 406: 6.7925e-04; Loss1: 6.7198e-04; Loss2: 7.2744e-06
# Training Epoch: 407
# Average Training Loss for Epoch 407: 6.7920e-04; Loss1: 6.7214e-04; Loss2: 7.0628e-06
# Training Epoch: 408
# Average Training Loss for Epoch 408: 6.7921e-04; Loss1: 6.7193e-04; Loss2: 7.2721e-06
# Training Epoch: 409
# Average Training Loss for Epoch 409: 6.7921e-04; Loss1: 6.7214e-04; Loss2: 7.0635e-06
# Training Epoch: 410
# Average Training Loss for Epoch 410: 6.7926e-04; Loss1: 6.7200e-04; Loss2: 7.2681e-06
# Training Epoch: 411
# Average Training Loss for Epoch 411: 6.7931e-04; Loss1: 6.7230e-04; Loss2: 7.0066e-06
# Training Epoch: 412
# Average Training Loss for Epoch 412: 6.7943e-04; Loss1: 6.7210e-04; Loss2: 7.3221e-06
# Training Epoch: 413
# Average Training Loss for Epoch 413: 6.7957e-04; Loss1: 6.7257e-04; Loss2: 6.9998e-06
# Training Epoch: 414
# Average Training Loss for Epoch 414: 6.7984e-04; Loss1: 6.7249e-04; Loss2: 7.3547e-06
# Training Epoch: 415
# Average Training Loss for Epoch 415: 6.8005e-04; Loss1: 6.7312e-04; Loss2: 6.9352e-06
# Training Epoch: 416
# Average Training Loss for Epoch 416: 6.8031e-04; Loss1: 6.7290e-04; Loss2: 7.4103e-06
# Training Epoch: 417
# Average Training Loss for Epoch 417: 6.8018e-04; Loss1: 6.7333e-04; Loss2: 6.8551e-06
# Training Epoch: 418
# Average Training Loss for Epoch 418: 6.7999e-04; Loss1: 6.7253e-04; Loss2: 7.4617e-06
# Training Epoch: 419
# Average Training Loss for Epoch 419: 6.7967e-04; Loss1: 6.7275e-04; Loss2: 6.9285e-06
# Training Epoch: 420
# Average Training Loss for Epoch 420: 6.7951e-04; Loss1: 6.7214e-04; Loss2: 7.3743e-06
# Training Epoch: 421
# Average Training Loss for Epoch 421: 6.7928e-04; Loss1: 6.7231e-04; Loss2: 6.9621e-06
# Training Epoch: 422
# Average Training Loss for Epoch 422: 6.7921e-04; Loss1: 6.7187e-04; Loss2: 7.3372e-06
# Training Epoch: 423
# Average Training Loss for Epoch 423: 6.7910e-04; Loss1: 6.7210e-04; Loss2: 7.0080e-06
# Training Epoch: 424
# Average Training Loss for Epoch 424: 6.7911e-04; Loss1: 6.7181e-04; Loss2: 7.3031e-06
# Training Epoch: 425
# Average Training Loss for Epoch 425: 6.7904e-04; Loss1: 6.7203e-04; Loss2: 7.0126e-06
# Training Epoch: 426
# Average Training Loss for Epoch 426: 6.7909e-04; Loss1: 6.7179e-04; Loss2: 7.2983e-06
# Training Epoch: 427
# Average Training Loss for Epoch 427: 6.7907e-04; Loss1: 6.7206e-04; Loss2: 7.0067e-06
# Training Epoch: 428
# Average Training Loss for Epoch 428: 6.7916e-04; Loss1: 6.7184e-04; Loss2: 7.3204e-06
# Training Epoch: 429
# Average Training Loss for Epoch 429: 6.7922e-04; Loss1: 6.7227e-04; Loss2: 6.9523e-06
# Training Epoch: 430
# Average Training Loss for Epoch 430: 6.7935e-04; Loss1: 6.7198e-04; Loss2: 7.3669e-06
# Training Epoch: 431
# Average Training Loss for Epoch 431: 6.7941e-04; Loss1: 6.7245e-04; Loss2: 6.9560e-06
# Training Epoch: 432
# Average Training Loss for Epoch 432: 6.7959e-04; Loss1: 6.7224e-04; Loss2: 7.3455e-06
# Training Epoch: 433
# Average Training Loss for Epoch 433: 6.7956e-04; Loss1: 6.7264e-04; Loss2: 6.9260e-06
# Training Epoch: 434
# Average Training Loss for Epoch 434: 6.7963e-04; Loss1: 6.7220e-04; Loss2: 7.4313e-06
# Training Epoch: 435
# Average Training Loss for Epoch 435: 6.7947e-04; Loss1: 6.7253e-04; Loss2: 6.9400e-06
# Training Epoch: 436
# Average Training Loss for Epoch 436: 6.7941e-04; Loss1: 6.7201e-04; Loss2: 7.3965e-06
# Training Epoch: 437
# Average Training Loss for Epoch 437: 6.7922e-04; Loss1: 6.7232e-04; Loss2: 6.9030e-06
# Training Epoch: 438
# Average Training Loss for Epoch 438: 6.7912e-04; Loss1: 6.7175e-04; Loss2: 7.3770e-06
# Training Epoch: 439
# Average Training Loss for Epoch 439: 6.7896e-04; Loss1: 6.7199e-04; Loss2: 6.9671e-06
# Training Epoch: 440
# Average Training Loss for Epoch 440: 6.7895e-04; Loss1: 6.7162e-04; Loss2: 7.3298e-06
# Training Epoch: 441
# Average Training Loss for Epoch 441: 6.7884e-04; Loss1: 6.7186e-04; Loss2: 6.9864e-06
# Training Epoch: 442
# Average Training Loss for Epoch 442: 6.7887e-04; Loss1: 6.7154e-04; Loss2: 7.3265e-06
# Training Epoch: 443
# Average Training Loss for Epoch 443: 6.7883e-04; Loss1: 6.7183e-04; Loss2: 6.9952e-06
# Training Epoch: 444
# Average Training Loss for Epoch 444: 6.7891e-04; Loss1: 6.7159e-04; Loss2: 7.3203e-06
# Training Epoch: 445
# Average Training Loss for Epoch 445: 6.7889e-04; Loss1: 6.7191e-04; Loss2: 6.9767e-06
# Training Epoch: 446
# Average Training Loss for Epoch 446: 6.7900e-04; Loss1: 6.7166e-04; Loss2: 7.3374e-06
# Training Epoch: 447
# Average Training Loss for Epoch 447: 6.7904e-04; Loss1: 6.7212e-04; Loss2: 6.9228e-06
# Training Epoch: 448
# Average Training Loss for Epoch 448: 6.7914e-04; Loss1: 6.7176e-04; Loss2: 7.3845e-06
# Training Epoch: 449
# Average Training Loss for Epoch 449: 6.7914e-04; Loss1: 6.7220e-04; Loss2: 6.9388e-06
# Training Epoch: 450
# Average Training Loss for Epoch 450: 6.7926e-04; Loss1: 6.7186e-04; Loss2: 7.4012e-06
# Training Epoch: 451
# Average Training Loss for Epoch 451: 6.7905e-04; Loss1: 6.7212e-04; Loss2: 6.9254e-06
# Training Epoch: 452
# Average Training Loss for Epoch 452: 6.7880e-04; Loss1: 6.7146e-04; Loss2: 7.3408e-06
# Training Epoch: 453
# Average Training Loss for Epoch 453: 6.7855e-04; Loss1: 6.7158e-04; Loss2: 6.9705e-06
# Training Epoch: 454
# Average Training Loss for Epoch 454: 6.7847e-04; Loss1: 6.7118e-04; Loss2: 7.2879e-06
# Training Epoch: 455
# ...
# Average Training Loss for Epoch 850: 6.7247e-04; Loss1: 6.6543e-04; Loss2: 7.0410e-06
# Training Epoch: 851
# Average Training Loss for Epoch 851: 6.7239e-04; Loss1: 6.6551e-04; Loss2: 6.8772e-06
# Training Epoch: 852
# Average Training Loss for Epoch 852: 6.7239e-04; Loss1: 6.6533e-04; Loss2: 7.0578e-06
# Training Epoch: 853
# Average Training Loss for Epoch 853: 6.7233e-04; Loss1: 6.6542e-04; Loss2: 6.9060e-06
# Training Epoch: 854
# Average Training Loss for Epoch 854: 6.7234e-04; Loss1: 6.6532e-04; Loss2: 7.0189e-06
# Training Epoch: 855
# Average Training Loss for Epoch 855: 6.7229e-04; Loss1: 6.6538e-04; Loss2: 6.9179e-06
# Training Epoch: 856
# Average Training Loss for Epoch 856: 6.7231e-04; Loss1: 6.6530e-04; Loss2: 7.0121e-06
# Training Epoch: 857
# Average Training Loss for Epoch 857: 6.7227e-04; Loss1: 6.6536e-04; Loss2: 6.9153e-06
# Training Epoch: 858
# Average Training Loss for Epoch 858: 6.7229e-04; Loss1: 6.6528e-04; Loss2: 7.0101e-06
# Training Epoch: 859
# Average Training Loss for Epoch 859: 6.7225e-04; Loss1: 6.6533e-04; Loss2: 6.9177e-06
# Training Epoch: 860
# Average Training Loss for Epoch 860: 6.7227e-04; Loss1: 6.6526e-04; Loss2: 7.0098e-06
# Training Epoch: 861
# Average Training Loss for Epoch 861: 6.7224e-04; Loss1: 6.6534e-04; Loss2: 6.9074e-06
# Training Epoch: 862
# Average Training Loss for Epoch 862: 6.7228e-04; Loss1: 6.6526e-04; Loss2: 7.0194e-06
# Training Epoch: 863
# Average Training Loss for Epoch 863: 6.7223e-04; Loss1: 6.6534e-04; Loss2: 6.8904e-06
# Training Epoch: 864
# Average Training Loss for Epoch 864: 6.7228e-04; Loss1: 6.6524e-04; Loss2: 7.0308e-06
# Training Epoch: 865
# Average Training Loss for Epoch 865: 6.7223e-04; Loss1: 6.6534e-04; Loss2: 6.8848e-06
# Training Epoch: 866
# Average Training Loss for Epoch 866: 6.7228e-04; Loss1: 6.6524e-04; Loss2: 7.0393e-06
# Training Epoch: 867
# Average Training Loss for Epoch 867: 6.7223e-04; Loss1: 6.6536e-04; Loss2: 6.8698e-06
# Training Epoch: 868
# Average Training Loss for Epoch 868: 6.7228e-04; Loss1: 6.6523e-04; Loss2: 7.0472e-06
# Training Epoch: 869
# Average Training Loss for Epoch 869: 6.7221e-04; Loss1: 6.6534e-04; Loss2: 6.8674e-06
# Training Epoch: 870
# Average Training Loss for Epoch 870: 6.7224e-04; Loss1: 6.6520e-04; Loss2: 7.0426e-06
# Training Epoch: 871
# Average Training Loss for Epoch 871: 6.7217e-04; Loss1: 6.6529e-04; Loss2: 6.8757e-06
# Training Epoch: 872
# Average Training Loss for Epoch 872: 6.7220e-04; Loss1: 6.6517e-04; Loss2: 7.0329e-06
# Training Epoch: 873
# Average Training Loss for Epoch 873: 6.7214e-04; Loss1: 6.6527e-04; Loss2: 6.8695e-06
# Training Epoch: 874
# Average Training Loss for Epoch 874: 6.7216e-04; Loss1: 6.6511e-04; Loss2: 7.0438e-06
# Training Epoch: 875
# Average Training Loss for Epoch 875: 6.7210e-04; Loss1: 6.6521e-04; Loss2: 6.8851e-06
# Training Epoch: 876
# Average Training Loss for Epoch 876: 6.7213e-04; Loss1: 6.6510e-04; Loss2: 7.0236e-06
# Training Epoch: 877
# Average Training Loss for Epoch 877: 6.7207e-04; Loss1: 6.6517e-04; Loss2: 6.8936e-06
# Training Epoch: 878
# Average Training Loss for Epoch 878: 6.7209e-04; Loss1: 6.6507e-04; Loss2: 7.0196e-06
# Training Epoch: 879
# Average Training Loss for Epoch 879: 6.7205e-04; Loss1: 6.6516e-04; Loss2: 6.8847e-06
# Training Epoch: 880
# Average Training Loss for Epoch 880: 6.7207e-04; Loss1: 6.6504e-04; Loss2: 7.0263e-06
# Training Epoch: 881
# Average Training Loss for Epoch 881: 6.7202e-04; Loss1: 6.6514e-04; Loss2: 6.8870e-06
# Training Epoch: 882
# Average Training Loss for Epoch 882: 6.7206e-04; Loss1: 6.6502e-04; Loss2: 7.0379e-06
# Training Epoch: 883
# Average Training Loss for Epoch 883: 6.7201e-04; Loss1: 6.6513e-04; Loss2: 6.8849e-06
# Training Epoch: 884
# Average Training Loss for Epoch 884: 6.7205e-04; Loss1: 6.6502e-04; Loss2: 7.0316e-06
# Training Epoch: 885
# Average Training Loss for Epoch 885: 6.7199e-04; Loss1: 6.6511e-04; Loss2: 6.8824e-06
# Training Epoch: 886
# Average Training Loss for Epoch 886: 6.7203e-04; Loss1: 6.6501e-04; Loss2: 7.0273e-06
# Training Epoch: 887
# Average Training Loss for Epoch 887: 6.7198e-04; Loss1: 6.6511e-04; Loss2: 6.8686e-06
# Training Epoch: 888
# Average Training Loss for Epoch 888: 6.7202e-04; Loss1: 6.6497e-04; Loss2: 7.0436e-06
# Training Epoch: 889
# Average Training Loss for Epoch 889: 6.7196e-04; Loss1: 6.6509e-04; Loss2: 6.8731e-06
# Training Epoch: 890
# Average Training Loss for Epoch 890: 6.7200e-04; Loss1: 6.6497e-04; Loss2: 7.0311e-06
# Training Epoch: 891
# Average Training Loss for Epoch 891: 6.7194e-04; Loss1: 6.6506e-04; Loss2: 6.8755e-06
# Training Epoch: 892
# Average Training Loss for Epoch 892: 6.7197e-04; Loss1: 6.6494e-04; Loss2: 7.0301e-06
# Training Epoch: 893
# Average Training Loss for Epoch 893: 6.7191e-04; Loss1: 6.6505e-04; Loss2: 6.8638e-06
# Training Epoch: 894
# Average Training Loss for Epoch 894: 6.7194e-04; Loss1: 6.6490e-04; Loss2: 7.0370e-06
# Training Epoch: 895
# Average Training Loss for Epoch 895: 6.7188e-04; Loss1: 6.6500e-04; Loss2: 6.8762e-06
# Training Epoch: 896
# Average Training Loss for Epoch 896: 6.7190e-04; Loss1: 6.6487e-04; Loss2: 7.0294e-06
# Training Epoch: 897
# Average Training Loss for Epoch 897: 6.7186e-04; Loss1: 6.6498e-04; Loss2: 6.8757e-06
# Training Epoch: 898
# Average Training Loss for Epoch 898: 6.7189e-04; Loss1: 6.6486e-04; Loss2: 7.0281e-06
# Training Epoch: 899
# Average Training Loss for Epoch 899: 6.7183e-04; Loss1: 6.6495e-04; Loss2: 6.8814e-06
# Training Epoch: 900
# Average Training Loss for Epoch 900: 6.7186e-04; Loss1: 6.6484e-04; Loss2: 7.0215e-06
# Training Epoch: 901
# Average Training Loss for Epoch 901: 6.7178e-04; Loss1: 6.6490e-04; Loss2: 6.8804e-06
# Training Epoch: 902
# Average Training Loss for Epoch 902: 6.7179e-04; Loss1: 6.6478e-04; Loss2: 7.0060e-06
# Training Epoch: 903
# Average Training Loss for Epoch 903: 6.7174e-04; Loss1: 6.6485e-04; Loss2: 6.8909e-06
# Training Epoch: 904
# Average Training Loss for Epoch 904: 6.7175e-04; Loss1: 6.6475e-04; Loss2: 6.9981e-06
# Training Epoch: 905
# Average Training Loss for Epoch 905: 6.7171e-04; Loss1: 6.6480e-04; Loss2: 6.9069e-06
# Training Epoch: 906
# Average Training Loss for Epoch 906: 6.7172e-04; Loss1: 6.6473e-04; Loss2: 6.9884e-06
# Training Epoch: 907
# Average Training Loss for Epoch 907: 6.7169e-04; Loss1: 6.6478e-04; Loss2: 6.9073e-06
# Training Epoch: 908
# Average Training Loss for Epoch 908: 6.7170e-04; Loss1: 6.6470e-04; Loss2: 6.9992e-06
# Training Epoch: 909
# Average Training Loss for Epoch 909: 6.7167e-04; Loss1: 6.6476e-04; Loss2: 6.9129e-06
# Training Epoch: 910
# Average Training Loss for Epoch 910: 6.7169e-04; Loss1: 6.6470e-04; Loss2: 6.9863e-06
# Training Epoch: 911
# Average Training Loss for Epoch 911: 6.7166e-04; Loss1: 6.6475e-04; Loss2: 6.9061e-06
# Training Epoch: 912
# Average Training Loss for Epoch 912: 6.7168e-04; Loss1: 6.6468e-04; Loss2: 6.9959e-06
# Training Epoch: 913
# Average Training Loss for Epoch 913: 6.7164e-04; Loss1: 6.6475e-04; Loss2: 6.8930e-06
# Training Epoch: 914
# Average Training Loss for Epoch 914: 6.7167e-04; Loss1: 6.6467e-04; Loss2: 7.0058e-06
# Training Epoch: 915
# Average Training Loss for Epoch 915: 6.7163e-04; Loss1: 6.6474e-04; Loss2: 6.8873e-06
# Training Epoch: 916
# Average Training Loss for Epoch 916: 6.7167e-04; Loss1: 6.6465e-04; Loss2: 7.0259e-06
# Training Epoch: 917
# Average Training Loss for Epoch 917: 6.7163e-04; Loss1: 6.6476e-04; Loss2: 6.8744e-06
# Training Epoch: 918
# Average Training Loss for Epoch 918: 6.7167e-04; Loss1: 6.6465e-04; Loss2: 7.0256e-06
# Training Epoch: 919
# Average Training Loss for Epoch 919: 6.7161e-04; Loss1: 6.6474e-04; Loss2: 6.8704e-06
# Training Epoch: 920
# Average Training Loss for Epoch 920: 6.7165e-04; Loss1: 6.6462e-04; Loss2: 7.0216e-06
# Training Epoch: 921
# Average Training Loss for Epoch 921: 6.7158e-04; Loss1: 6.6472e-04; Loss2: 6.8646e-06
# Training Epoch: 922
# Average Training Loss for Epoch 922: 6.7161e-04; Loss1: 6.6459e-04; Loss2: 7.0212e-06
# Training Epoch: 923
# Average Training Loss for Epoch 923: 6.7155e-04; Loss1: 6.6468e-04; Loss2: 6.8767e-06
# Training Epoch: 924
# Average Training Loss for Epoch 924: 6.7157e-04; Loss1: 6.6457e-04; Loss2: 7.0072e-06
# Training Epoch: 925
# Average Training Loss for Epoch 925: 6.7152e-04; Loss1: 6.6464e-04; Loss2: 6.8764e-06
# Training Epoch: 926
# Average Training Loss for Epoch 926: 6.7154e-04; Loss1: 6.6453e-04; Loss2: 7.0076e-06
# Training Epoch: 927
# Average Training Loss for Epoch 927: 6.7149e-04; Loss1: 6.6460e-04; Loss2: 6.8855e-06
# Training Epoch: 928
# Average Training Loss for Epoch 928: 6.7151e-04; Loss1: 6.6451e-04; Loss2: 6.9996e-06
# Training Epoch: 929
# Average Training Loss for Epoch 929: 6.7146e-04; Loss1: 6.6457e-04; Loss2: 6.8926e-06
# Training Epoch: 930
# Average Training Loss for Epoch 930: 6.7149e-04; Loss1: 6.6449e-04; Loss2: 6.9965e-06
# Training Epoch: 931
# Average Training Loss for Epoch 931: 6.7145e-04; Loss1: 6.6456e-04; Loss2: 6.8855e-06
# Training Epoch: 932
# Average Training Loss for Epoch 932: 6.7147e-04; Loss1: 6.6448e-04; Loss2: 6.9971e-06
# Training Epoch: 933
# Average Training Loss for Epoch 933: 6.7143e-04; Loss1: 6.6454e-04; Loss2: 6.8894e-06
# Training Epoch: 934
# Average Training Loss for Epoch 934: 6.7146e-04; Loss1: 6.6446e-04; Loss2: 6.9990e-06
# Training Epoch: 935
# Average Training Loss for Epoch 935: 6.7141e-04; Loss1: 6.6454e-04; Loss2: 6.8752e-06
# Training Epoch: 936
# Average Training Loss for Epoch 936: 6.7144e-04; Loss1: 6.6443e-04; Loss2: 7.0103e-06
# Training Epoch: 937
# Average Training Loss for Epoch 937: 6.7140e-04; Loss1: 6.6452e-04; Loss2: 6.8720e-06
# Training Epoch: 938
# Average Training Loss for Epoch 938: 6.7143e-04; Loss1: 6.6442e-04; Loss2: 7.0074e-06
# Training Epoch: 939
# Average Training Loss for Epoch 939: 6.7138e-04; Loss1: 6.6450e-04; Loss2: 6.8768e-06
# Training Epoch: 940
# Average Training Loss for Epoch 940: 6.7141e-04; Loss1: 6.6440e-04; Loss2: 7.0100e-06
# Training Epoch: 941
# Average Training Loss for Epoch 941: 6.7136e-04; Loss1: 6.6449e-04; Loss2: 6.8706e-06
# Training Epoch: 942
# Average Training Loss for Epoch 942: 6.7140e-04; Loss1: 6.6437e-04; Loss2: 7.0248e-06
# Training Epoch: 943
# Average Training Loss for Epoch 943: 6.7134e-04; Loss1: 6.6446e-04; Loss2: 6.8789e-06
# Training Epoch: 944
# Average Training Loss for Epoch 944: 6.7137e-04; Loss1: 6.6436e-04; Loss2: 7.0114e-06
# Training Epoch: 945
# Average Training Loss for Epoch 945: 6.7132e-04; Loss1: 6.6445e-04; Loss2: 6.8673e-06
# Training Epoch: 946
# Average Training Loss for Epoch 946: 6.7134e-04; Loss1: 6.6433e-04; Loss2: 7.0124e-06
# Training Epoch: 947
# Average Training Loss for Epoch 947: 6.7129e-04; Loss1: 6.6441e-04; Loss2: 6.8775e-06
# Training Epoch: 948
# Average Training Loss for Epoch 948: 6.7131e-04; Loss1: 6.6431e-04; Loss2: 6.9999e-06
# Training Epoch: 949
# Average Training Loss for Epoch 949: 6.7126e-04; Loss1: 6.6438e-04; Loss2: 6.8788e-06
# Training Epoch: 950
# Average Training Loss for Epoch 950: 6.7129e-04; Loss1: 6.6429e-04; Loss2: 7.0007e-06
# Training Epoch: 951
# Average Training Loss for Epoch 951: 6.7122e-04; Loss1: 6.6435e-04; Loss2: 6.8753e-06
# Training Epoch: 952
# Average Training Loss for Epoch 952: 6.7123e-04; Loss1: 6.6424e-04; Loss2: 6.9877e-06
# Training Epoch: 953
# Average Training Loss for Epoch 953: 6.7118e-04; Loss1: 6.6428e-04; Loss2: 6.8951e-06
# Training Epoch: 954
# Average Training Loss for Epoch 954: 6.7119e-04; Loss1: 6.6422e-04; Loss2: 6.9724e-06
# Training Epoch: 955
# Average Training Loss for Epoch 955: 6.7116e-04; Loss1: 6.6425e-04; Loss2: 6.9049e-06
# Training Epoch: 956
# Average Training Loss for Epoch 956: 6.7116e-04; Loss1: 6.6420e-04; Loss2: 6.9659e-06
# Training Epoch: 957
# Average Training Loss for Epoch 957: 6.7114e-04; Loss1: 6.6422e-04; Loss2: 6.9114e-06
# Training Epoch: 958
# Average Training Loss for Epoch 958: 6.7114e-04; Loss1: 6.6418e-04; Loss2: 6.9634e-06
# Training Epoch: 959
# Average Training Loss for Epoch 959: 6.7112e-04; Loss1: 6.6421e-04; Loss2: 6.9090e-06
# Training Epoch: 960
# Average Training Loss for Epoch 960: 6.7112e-04; Loss1: 6.6416e-04; Loss2: 6.9676e-06
# Training Epoch: 961
# Average Training Loss for Epoch 961: 6.7110e-04; Loss1: 6.6420e-04; Loss2: 6.9028e-06
# Training Epoch: 962
# Average Training Loss for Epoch 962: 6.7111e-04; Loss1: 6.6414e-04; Loss2: 6.9697e-06
# Training Epoch: 963
# Average Training Loss for Epoch 963: 6.7108e-04; Loss1: 6.6418e-04; Loss2: 6.8994e-06
# Training Epoch: 964
# Average Training Loss for Epoch 964: 6.7110e-04; Loss1: 6.6413e-04; Loss2: 6.9735e-06
# Training Epoch: 965
# Average Training Loss for Epoch 965: 6.7107e-04; Loss1: 6.6418e-04; Loss2: 6.8892e-06
# Training Epoch: 966
# Average Training Loss for Epoch 966: 6.7110e-04; Loss1: 6.6411e-04; Loss2: 6.9921e-06
# Training Epoch: 967
# Average Training Loss for Epoch 967: 6.7106e-04; Loss1: 6.6418e-04; Loss2: 6.8787e-06
# Training Epoch: 968
# Average Training Loss for Epoch 968: 6.7110e-04; Loss1: 6.6411e-04; Loss2: 6.9917e-06
# Training Epoch: 969
# Average Training Loss for Epoch 969: 6.7105e-04; Loss1: 6.6418e-04; Loss2: 6.8736e-06
# Training Epoch: 970
# Average Training Loss for Epoch 970: 6.7109e-04; Loss1: 6.6410e-04; Loss2: 6.9917e-06
# Training Epoch: 971
# Average Training Loss for Epoch 971: 6.7104e-04; Loss1: 6.6418e-04; Loss2: 6.8624e-06
# Training Epoch: 972
# Average Training Loss for Epoch 972: 6.7106e-04; Loss1: 6.6406e-04; Loss2: 7.0044e-06
# Training Epoch: 973
# Average Training Loss for Epoch 973: 6.7101e-04; Loss1: 6.6414e-04; Loss2: 6.8726e-06
# Training Epoch: 974
# Average Training Loss for Epoch 974: 6.7103e-04; Loss1: 6.6404e-04; Loss2: 6.9878e-06
# Training Epoch: 975
# Average Training Loss for Epoch 975: 6.7098e-04; Loss1: 6.6411e-04; Loss2: 6.8687e-06
# Training Epoch: 976
# Average Training Loss for Epoch 976: 6.7100e-04; Loss1: 6.6401e-04; Loss2: 6.9893e-06
# Training Epoch: 977
# Average Training Loss for Epoch 977: 6.7095e-04; Loss1: 6.6407e-04; Loss2: 6.8805e-06
# Training Epoch: 978
# Average Training Loss for Epoch 978: 6.7096e-04; Loss1: 6.6399e-04; Loss2: 6.9778e-06
# Training Epoch: 979
# Average Training Loss for Epoch 979: 6.7093e-04; Loss1: 6.6405e-04; Loss2: 6.8801e-06
# Training Epoch: 980
# Average Training Loss for Epoch 980: 6.7094e-04; Loss1: 6.6396e-04; Loss2: 6.9772e-06
# Training Epoch: 981
# Average Training Loss for Epoch 981: 6.7090e-04; Loss1: 6.6401e-04; Loss2: 6.8885e-06
# Training Epoch: 982
# Average Training Loss for Epoch 982: 6.7092e-04; Loss1: 6.6395e-04; Loss2: 6.9712e-06
# Training Epoch: 983
# Average Training Loss for Epoch 983: 6.7088e-04; Loss1: 6.6400e-04; Loss2: 6.8840e-06
# Training Epoch: 984
# Average Training Loss for Epoch 984: 6.7090e-04; Loss1: 6.6392e-04; Loss2: 6.9776e-06
# Training Epoch: 985
# Average Training Loss for Epoch 985: 6.7087e-04; Loss1: 6.6398e-04; Loss2: 6.8841e-06
# Training Epoch: 986
# Average Training Loss for Epoch 986: 6.7089e-04; Loss1: 6.6391e-04; Loss2: 6.9850e-06
# Training Epoch: 987
# Average Training Loss for Epoch 987: 6.7085e-04; Loss1: 6.6396e-04; Loss2: 6.8857e-06
# Training Epoch: 988
# Average Training Loss for Epoch 988: 6.7088e-04; Loss1: 6.6390e-04; Loss2: 6.9775e-06
# Training Epoch: 989
# Average Training Loss for Epoch 989: 6.7084e-04; Loss1: 6.6396e-04; Loss2: 6.8721e-06
# Training Epoch: 990
# Average Training Loss for Epoch 990: 6.7086e-04; Loss1: 6.6388e-04; Loss2: 6.9847e-06
# Training Epoch: 991
# Average Training Loss for Epoch 991: 6.7082e-04; Loss1: 6.6394e-04; Loss2: 6.8748e-06
# Training Epoch: 992
# Average Training Loss for Epoch 992: 6.7085e-04; Loss1: 6.6386e-04; Loss2: 6.9833e-06
# Training Epoch: 993
# Average Training Loss for Epoch 993: 6.7080e-04; Loss1: 6.6394e-04; Loss2: 6.8649e-06
# Training Epoch: 994
# Average Training Loss for Epoch 994: 6.7083e-04; Loss1: 6.6383e-04; Loss2: 6.9939e-06
# Training Epoch: 995
# Average Training Loss for Epoch 995: 6.7078e-04; Loss1: 6.6391e-04; Loss2: 6.8715e-06
# Training Epoch: 996
# Average Training Loss for Epoch 996: 6.7081e-04; Loss1: 6.6383e-04; Loss2: 6.9819e-06
# Training Epoch: 997
# Average Training Loss for Epoch 997: 6.7076e-04; Loss1: 6.6390e-04; Loss2: 6.8636e-06
# Training Epoch: 998
# Average Training Loss for Epoch 998: 6.7078e-04; Loss1: 6.6379e-04; Loss2: 6.9892e-06
# Training Epoch: 999
# Average Training Loss for Epoch 999: 6.7073e-04; Loss1: 6.6386e-04; Loss2: 6.8721e-06
# Training Epoch: 1000
# Average Training Loss for Epoch 1000: 6.7075e-04; Loss1: 6.6378e-04; Loss2: 6.9745e-06

# %%
torch.save(model_h, 'reaction_diffusion_model_h.pth')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Train Loss')
plt.plot(train_losses1, label='Train Loss 1')
plt.plot(train_losses2, label='Train Loss 2')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.yscale('log')
plt.title('Training Losses Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Evaluate

# %%
def optimize_g(lace, y):
    lace_mean = torch.mean(lace)
    y_mean = torch.mean(y)

    mu_numerator = torch.sum((lace - lace_mean) * (y - y_mean))
    mu_denominator = torch.sum((lace - lace_mean) ** 2)
    mu = mu_numerator / mu_denominator

    return mu

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class LinearRegressionLayer(nn.Module):
    def __init__(self, input_size, output_size):
        super(LinearRegressionLayer, self).__init__()
        self.linear = nn.Linear(input_size, output_size, bias = False)
    
    def forward(self, x):
        return self.linear(x)

import torch
from torch import optim, nn
from torch.utils.data import DataLoader, TensorDataset

def train_linear_layer(model, linear_layer, x, lace, y, epochs=100, learning_rate=0.001, batch_size=512):
    for param in model.parameters():
        param.requires_grad = False
    
    optimizer = optim.Adam(linear_layer.parameters(), lr=learning_rate)
    criterion = nn.MSELoss()

    dataset = TensorDataset(x, y, lace)
    data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
    scheduler = StepLR(optimizer, step_size=50, gamma=0.9)

    for epoch in range(epochs):
        model.eval()
        total_loss = 0

        for batch_x, batch_y, batch_lace in data_loader:
            inputs = torch.cat((batch_x, batch_lace), dim = 1)
            outputs = model(inputs)
            predictions = linear_layer(outputs)

            loss = criterion(predictions, batch_y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            
        scheduler.step()

        # print(f'Epoch {epoch+1}, Loss: {total_loss / len(data_loader)}')

# %%
model_h_init = ParaModel(input_dim, hidden_dims, m_dim)
model_h = torch.load('reaction_diffusion_model_h.pth')

# %%
linear_init = LinearRegressionLayer(m_dim, 1)
linear_h = LinearRegressionLayer(m_dim, 1)

# %%
dataloader = DataLoader(dataset, batch_size=len(dataset), shuffle=False)
for x, y, lace in dataloader:
    break
y_g = y

err_history_init = []
iterations = 15
inputs = torch.cat((x, lace), dim =1)
for iteration in range(iterations):
    mu_init = optimize_g(lace, y_g)
    print(iteration)
    y_h = y - mu_init * lace
    train_linear_layer(model_h_init, linear_init, x, lace, y_h, epochs=300, learning_rate=0.001)
    y_g = y - linear_init(model_h_init(inputs)).detach()
    err = torch.norm(y - y_h- y_g)
    print(err)
    err_history_init.append(err.item())
# Out:
# tensor(-0.1596)
# tensor(3.0021)
# tensor(-0.0955)
# tensor(2.5298)
# tensor(-0.1005)
# tensor(2.4675)
# tensor(-0.0969)
# tensor(2.4319)
# tensor(-0.0917)
# tensor(2.4081)
# tensor(-0.0862)
# tensor(2.4047)
# tensor(-0.0811)
# tensor(2.3792)
# tensor(-0.0763)
# tensor(2.3744)
# tensor(-0.0721)
# tensor(2.3677)
# tensor(-0.0681)
# tensor(2.3497)
# tensor(-0.0644)
# tensor(2.3410)
# tensor(-0.0611)
# tensor(2.3332)
# tensor(-0.0580)
# tensor(2.3243)
# tensor(-0.0551)
# tensor(2.3188)
# tensor(-0.0524)
# tensor(2.3098)

# %%
dataloader = DataLoader(dataset, batch_size=len(dataset), shuffle=False)
for x, y, lace in dataloader:
    break
y_g = y

err_history_h = []
iterations = 15
inputs = torch.cat((x, lace), dim =1)
for iteration in range(iterations):
    mu_h = optimize_g(lace, y_g)
    print(iteration)
    y_h = y - mu_h * lace
    train_linear_layer(model_h, linear_h, x, lace, y_h, epochs=300, learning_rate=0.001)
    y_g = y - linear_h(model_h(inputs)).detach()
    err = torch.norm(y - y_h- y_g)
    print(err)
    err_history_h.append(err.item())
# Out:
# 0
# tensor(0.2914)
# 1
# tensor(0.1757)
# 2
# tensor(0.1735)
# 3
# tensor(0.1948)
# 4
# tensor(0.1717)
# 5
# tensor(0.1718)
# 6
# tensor(0.1749)
# 7
# tensor(0.1796)
# 8
# tensor(0.1747)
# 9
# tensor(0.1740)
# 10
# tensor(0.1733)
# 11
# tensor(0.1878)
# 12
# tensor(0.1958)
# 13
# tensor(0.1751)
# 14
# tensor(0.1717)

# %%
# err_history_diff_init = [err_history_init[i] - err_history_init[-1] for i in range(len(err_history_init))]
# err_history_diff_h = [err_history_h[i] - err_history_h[-1] for i in range(len(err_history_h))]

plt.figure()
plt.plot(err_history_init, label = 'w/o training')
plt.legend()
plt.yscale('log')


plt.figure()
plt.plot(err_history_h, label = 'with training')
plt.legend()
plt.yscale('log')

# %%
np.save('err_history_init.npy', err_history_init)
np.save('err_history_h.npy', err_history_h)
